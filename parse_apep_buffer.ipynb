# %% [markdown]
# <a id=start></a>
# # Parser for Apophis Testing
#
# Includes toggle for plotting original or buffered data. <br>
# Does not include any fixes for bad data
#
# #### Shortcuts to Sections:
# * [Setup](#start)
# * [Load & Parse Data](#parsing)
# * [Save Parsed Data to Frickle file](#saveFrickle)
# * [Plotting Section](#plotting)
#
# ### In cell below:
# > Enter data path, file name. <br>
# > Choose 'original' or 'repeat'.<br>
# > Specific plot parameters (e.g. time range) can be adjusted in the last cell.

# %%
# path = "../delamere_data/delamere_flight_data/" # Path to saved file on local machine
# file_name = "data_file_115k_usbmodem145101.txt"
# path = "kinetx_data/dallas/" # Path to saved file on local machine
# file_name = "Dallas1_FlightData_5-16-2021.txt"
# file_name = "Flight-data_file_230k_1-05_16_21.txt"

# path ="./"
# file_name = "20230515T171854Z_data_usbserial-FT611XTT3_230400_15.bin"
# path = "./data/"
# file_name = "20230614T193044Z_data_usbserial-FT611XTT3_230400_shield29-first-plasma-test-C_29.bin"
# path = "./data/apophisChamber/19June2023/"
# file_name = "20230619T164554Z_data_usbserial-FT611XTT3_230400_shield28-plasmatest-rollA_28.bin"
# file_name = "20230619T170046Z_data_usbserial-FT611XTT3_230400_shield28-plasmatest-pitchA_28.bin"
# file_name = "20230619T171535Z_data_usbserial-FT611XTT3_230400_shield28-plasmatest-rollB_28.bin"
# file_name = "20230619T172226Z_data_usbserial-FT611XTT3_230400_shield28-plasmatest-pitchB_28.bin"

# path = "./data/apophisChamber/21June/"
# # file_name = '20230621T162132Z_data_usbserial-FT611XTT3_230400_shield29-plasmatest-rollA_29.bin'
# # file_name = '20230621T163500Z_data_usbserial-FT611XTT3_230400_shield29-plasmatest-pitchA_29.bin'
# # file_name = '20230621T164914Z_data_usbserial-FT611XTT3_230400_shield29-plasmatest-rollB_29.bin'
# # file_name = '20230621T165241Z_data_usbserial-FT611XTT3_230400_shield29-plasmatest-rollC_29.bin'
# file_name = '20230621T170012Z_data_usbserial-FT611XTT3_230400_shield29-plasmatest-pitchB_29.bin'

# path = "./data/apophisChamber/03July2023/"
# file_name = "20230703T171632Z_data_usbserial-FT611XTT3_230400_shield30-plasmatest-rollA_30.bin"
# file_name = "20230703T173220Z_data_usbserial-FT611XTT3_230400_shield30-plasmatest-pitchA2_30.bin"
# file_name = "20230703T174926Z_data_usbserial-FT611XTT3_230400_shield30-plasmatest-rollB_30.bin"
# file_name = "20230703T175645Z_data_usbserial-FT611XTT3_230400_shield30-plasmatest-pitchB_30.bin"

# path = "./data/apophisChamber/05July2023/"
# # file_name = "20230705T184852Z_data_usbserial-FT611XTT3_230400_shield31-plasmatest-rollA_31.bin"
# # file_name = "20230705T191155Z_data_usbserial-FT611XTT3_230400_shield31-plasmatest-pitchA_31.bin"
# # file_name = "20230705T192810Z_data_usbserial-FT611XTT3_230400_shield31-plasmatest-rollB_31.bin"
# file_name = "20230705T193554Z_data_usbserial-FT611XTT3_230400_shield31-plasmatest-pitchB_31.bin"
path = "./apep1/"
file_name = "BOB28_36_386_launch_swarm_udpwrite_playback.bin" 
# file_name = "BOB30_36_387_launch_swarm_udpwrite_playback.bin" 
# file_name = "BOB31_36_388_launch_swarm_udpwrite.bin"

plottype = 'original' # Choose 'original' or 'repeat'

interruptOffset = 0 # Offset between interrupt timestamps and imu/sweep timestamps
# interruptOffset = -8.0062 # KiNET-X Mission's time offset between interrupt timestamps and imu/sweep timestamps
T0_offset = 0 # Right now ONLY affect the sweepSampleTime NOT sweepTime or imuTime
# T0_offset = 572.732

# %%
import sys
import matplotlib
if 'matplotlib.pyplot' not in sys.modules.keys():
    matplotlib.use("Agg")
import matplotlib.pyplot as plt
import json
import numpy as np

# %matplotlib notebook

dataFile = path + file_name

class IMUData():
    def __init__(self):

        self.time = []; self.temp = []
        self.ax = []; self.ay = []; self.az = []
        self.mx = []; self.my = []; self.mz = []
        self.gx = []; self.gy = []; self.gz = []
        
        self.timeRpt = []; self.tempRpt = []
        self.axRpt = []; self.ayRpt = []; self.azRpt = []
        self.mxRpt = []; self.myRpt = []; self.mzRpt = []
        self.gxRpt = []; self.gyRpt = []; self.gzRpt = []
        
class SweepData():
    def __init__(self):
        self.time = []
        self.pip0 = []; self.pip1 = [];
        
        self.timeRpt = []
        self.pip0Rpt = []; self.pip1Rpt = [];
        
class PayloadData():
    def __init__(self):
        self.rawData = ''
        self.imu = IMUData()
        self.sweeps = SweepData()
        self.macAddress = ''
        self.rssiData = []
        self.shieldID = 0
        
# Functions for merging bytes
def combine2(a, b):
    return (a << 8) | b
def combine4(a, b, c, d):
    return (a << 24) | (b << 16) | (c << 8) | d

# Functions for saving data
def convertDataToLists(dataSet):
    dataSet.imu.ax = dataSet.imu.ax.tolist()
    dataSet.imu.ay = dataSet.imu.ay.tolist()
    dataSet.imu.az = dataSet.imu.az.tolist()
    dataSet.imu.mx = dataSet.imu.mx.tolist()
    dataSet.imu.my = dataSet.imu.my.tolist()
    dataSet.imu.mz = dataSet.imu.mz.tolist()
    dataSet.imu.gx = dataSet.imu.gx.tolist()
    dataSet.imu.gy = dataSet.imu.gy.tolist()
    dataSet.imu.gz = dataSet.imu.gz.tolist()
    dataSet.imu.temp = dataSet.imu.temp.tolist()
    dataSet.imu.time = dataSet.imu.time.tolist()
    dataSet.sweeps.time = dataSet.sweeps.time.tolist()
    dataSet.sweeps.pip0 = dataSet.sweeps.pip0.tolist()
    dataSet.sweeps.pip1 = dataSet.sweeps.pip1.tolist()
    
    dataSet.imu.axRpt = dataSet.imu.axRpt.tolist()
    dataSet.imu.ayRpt = dataSet.imu.ayRpt.tolist()
    dataSet.imu.azRpt = dataSet.imu.azRpt.tolist()
    dataSet.imu.mxRpt = dataSet.imu.mxRpt.tolist()
    dataSet.imu.myRpt = dataSet.imu.myRpt.tolist()
    dataSet.imu.mzRpt = dataSet.imu.mzRpt.tolist()
    dataSet.imu.gxRpt = dataSet.imu.gxRpt.tolist()
    dataSet.imu.gyRpt = dataSet.imu.gyRpt.tolist()
    dataSet.imu.gzRpt = dataSet.imu.gzRpt.tolist()
    dataSet.imu.tempRpt = dataSet.imu.tempRpt.tolist()
    dataSet.imu.timeRpt = dataSet.imu.timeRpt.tolist()
    dataSet.sweeps.timeRpt = dataSet.sweeps.timeRpt.tolist()
    dataSet.sweeps.pip0Rpt = dataSet.sweeps.pip0Rpt.tolist()
    dataSet.sweeps.pip1Rpt = dataSet.sweeps.pip1Rpt.tolist()
    return dataSet

def makeJSONFile (fname, payloadData):
    f = open(fname, 'w')
    # Convert into lists and dictionaries for JSON storage
    payloadData = convertDataToLists(payloadData)
    JSONDict = {}
    # First the IMU data
    imu = payloadData.imu
    imuData = {"time":imu.time, "temp":imu.temp,
               "ax":imu.ax, "ay":imu.ay, "az":imu.az,
               "mx":imu.mx, "my":imu.my, "mz":imu.mz,
               "gx":imu.gx, "gy":imu.gy, "gz":imu.gz}
    JSONDict["imu"] = imuData
    # Then the sweep data
    sweeps = payloadData.sweeps
    sweepData = {"id":sweeps.payloadID, "time":sweeps.time, "pip0":sweeps.pip0, "pip1":sweeps.pip1}
    JSONDict["sweeps"] = sweepData

    json.dump(JSONDict, f)
    f.close()

# %% [markdown]
# <a id="parsing"></a>
# ### Load & Parse Data

# %%
########### Load the data file ###########
f = open(dataFile, 'rb')
rawData = f.read()

# Create payload objects and store parsed data
mainPIPData = PayloadData()
mainPIPData.rawData = rawData
payloads = [mainPIPData]

########### Parse by data type for each payload ###########
strict_parse = False # Require a pound symbol at the end of the data
for payload in payloads:
    payloadrawData = payload.rawData
    imu = []
    sweeps = []
    imuRpt = []
    sweepsRpt = []
    interrupt = []
    # 2 PIPs with 28 2-byte samples + 4-byte timestamp + ID
    sweepSamples = 28
    numSweepBytes = sweepSamples * 2 * 2 + 4 + 1
    # 9 2-byte data points + 2-byte temp + 4-byte timestamp
    numIMUBytes = 24
    # Barium interrupt
    numInterruptBytes = 4
    
    pntr = 0
    while pntr < len(payloadrawData):
        # Check message start sentinels and not at end
        if payloadrawData[pntr] == 35 and (len(payloadrawData)-pntr) >= numIMUBytes:
#         if payloadrawData[pntr] == '#' and (len(payloadrawData)-pntr) >= numIMUBytes:
            if payloadrawData[pntr+1] == 73:
#             if payloadrawData[pntr+1] == 'I':
                # If not the last, check message end sentinel
                if pntr+2+numIMUBytes < len(payloadrawData):
                    if not strict_parse or payloadrawData[pntr+2+numIMUBytes] == 35:
#                     if not strict_parse or payloadrawData[pntr+2+numIMUBytes] == '#':
                        imu.append(payloadrawData[pntr+2:pntr+2+numIMUBytes])
                # Or just add the last message
                else:
                    imu.append(payloadrawData[pntr+2:pntr+2+numIMUBytes])
                pntr += 1
            elif payloadrawData[pntr+1] == 83:
#             elif payloadrawData[pntr+1] == 'S':
                if  pntr+2+numSweepBytes < len(payloadrawData):
                    if not strict_parse or payloadrawData[pntr+2+numSweepBytes] == 35:
                        sweeps.append(payloadrawData[pntr+2:pntr+2+numSweepBytes])
                else:
                    sweeps.append(payloadrawData[pntr+2:pntr+2+numSweepBytes])
                pntr += 1
            elif payloadrawData[pntr+1] == 74:
#             elif payloadrawData[pntr+1] == 'J':
                if pntr+2+numIMUBytes < len(payloadrawData):
                    if not strict_parse or payloadrawData[pntr+2+numIMUBytes] == 35:
                        imuRpt.append(payloadrawData[pntr+2:pntr+2+numIMUBytes])
                else:
                    imuRpt.append(payloadrawData[pntr+2:pntr+2+numIMUBytes])
                pntr += 1
#             elif payloadrawData[pntr+1] == 'T':
            elif payloadrawData[pntr+1] == 84:
                if  pntr+2+numSweepBytes < len(payloadrawData):
                    if not strict_parse or payloadrawData[pntr+2+numSweepBytes] == 35:
                        sweepsRpt.append(payloadrawData[pntr+2:pntr+2+numSweepBytes])
                else:
                    sweepsRpt.append(payloadrawData[pntr+2:pntr+2+numSweepBytes])
                pntr += 1
#             elif payloadrawData[pntr+1] == 'B':
            elif payloadrawData[pntr+1] == 66:
                if  pntr+2+numInterruptBytes < len(payloadrawData):
                    if not strict_parse or payloadrawData[pntr+2+numInterruptBytes] == 35:
                        interrupt.append(payloadrawData[pntr+2:pntr+2+numInterruptBytes])
                else:
                    interrupt.append(payloadrawData[pntr+2:pntr+2+numInterruptBytes])
                pntr += 1
            else:
                pntr += 1
        else:
            pntr += 1
    print("Num IMU Messages: %s" %len(imu))
    print("Num Sweep Messages: %s" %len(sweeps))
    print("Num IMU Messages (buffer): %s" %len(imuRpt))
    print("Num Sweep Messages (buffer): %s" %len(sweepsRpt))
    print("Num interrupt messages: %s" %len(interrupt))

    ########### Build data structures ###########
    # First the IMU/IMU Buffer
    imuTime = [];
    ax = []; ay = []; az = []
    mx = []; my = []; mz = []
    gx = []; gy = []; gz = []
    temp = [];
    
    imuTimeRpt = [];
    axRpt = []; ayRpt = []; azRpt = []
    mxRpt = []; myRpt = []; mzRpt = []
    gxRpt = []; gyRpt = []; gzRpt = []
    tempRpt = [];
    
    for i in imu:
        if len(i) == numIMUBytes:
            imuTime.append(combine4(i[3], i[2], i[1], i[0]))
            # The byte order is reversed, but the data sets are not
            ax.append(combine2(i[5], i[4]))
            ay.append(combine2(i[7], i[6]))
            az.append(combine2(i[9], i[8]))
            mx.append(combine2(i[11], i[10]))
            my.append(combine2(i[13], i[12]))
            mz.append(combine2(i[15], i[14]))
            gx.append(combine2(i[17], i[16]))
            gy.append(combine2(i[19], i[18]))
            gz.append(combine2(i[21], i[20]))
            temp.append(combine2(i[23], i[22]))
    
    for i in imuRpt:
        if len(i) == numIMUBytes:
            imuTimeRpt.append(combine4(i[3], i[2], i[1], i[0]))
            axRpt.append(combine2(i[5], i[4]))
            ayRpt.append(combine2(i[7], i[6]))
            azRpt.append(combine2(i[9], i[8]))
            mxRpt.append(combine2(i[11], i[10]))
            myRpt.append(combine2(i[13], i[12]))
            mzRpt.append(combine2(i[15], i[14]))
            gxRpt.append(combine2(i[17], i[16]))
            gyRpt.append(combine2(i[19], i[18]))
            gzRpt.append(combine2(i[21], i[20]))
            tempRpt.append(combine2(i[23], i[22]))

    imuTime = np.array(imuTime, dtype='uint32')
    ax = np.array(ax, dtype='int16')
    ay = np.array(ay, dtype='int16')
    az = np.array(az, dtype='int16')
    mx = np.array(mx, dtype='int16')
    my = np.array(my, dtype='int16')
    mz = np.array(mz, dtype='int16')
    gx = np.array(gx, dtype='int16')
    gy = np.array(gy, dtype='int16')
    gz = np.array(gz, dtype='int16')
    temp = np.array(temp, dtype='int16')
    
    imuTimeRpt = np.array(imuTimeRpt, dtype='uint32')
    axRpt = np.array(axRpt, dtype='int16')
    ayRpt = np.array(ayRpt, dtype='int16')
    azRpt = np.array(azRpt, dtype='int16')
    mxRpt = np.array(mxRpt, dtype='int16')
    myRpt = np.array(myRpt, dtype='int16')
    mzRpt = np.array(mzRpt, dtype='int16')
    gxRpt = np.array(gxRpt, dtype='int16')
    gyRpt = np.array(gyRpt, dtype='int16')
    gzRpt = np.array(gzRpt, dtype='int16')
    tempRpt = np.array(tempRpt, dtype='int16')

    payload.imu.time = imuTime
    payload.imu.ax = ax
    payload.imu.ay = ay
    payload.imu.az = az
    payload.imu.mx = mx
    payload.imu.my = my
    payload.imu.mz = mz
    payload.imu.gx = gx
    payload.imu.gy = gy
    payload.imu.gz = gz
    payload.imu.temp = temp
    
    payload.imu.timeRpt = imuTimeRpt
    payload.imu.axRpt = axRpt
    payload.imu.ayRpt = ayRpt
    payload.imu.azRpt = azRpt
    payload.imu.mxRpt = mxRpt
    payload.imu.myRpt = myRpt
    payload.imu.mzRpt = mzRpt
    payload.imu.gxRpt = gxRpt
    payload.imu.gyRpt = gyRpt
    payload.imu.gzRpt = gzRpt
    payload.imu.tempRpt = tempRpt

    # Then the sweeps
    payloadID = [];
    sweepTime = []
    allSweepsPIP0 = []
    individualSweepsPIP0 = []
    allSweepsPIP1 = []
    individualSweepsPIP1 = []
    PIP0StartByte = 4 + 1                             # Four for time, one payload ID  
    PIP0StopByte = PIP0StartByte + sweepSamples*2   # Number of samples, two bytes each
    PIP1StopByte = PIP0StopByte + sweepSamples*2      # Number of samples, two bytes each
    
    sweepTimeRpt = []
    allSweepsPIP0Rpt = []
    individualSweepsPIP0Rpt = []
    allSweepsPIP1Rpt = []
    individualSweepsPIP1Rpt = []
    PIP0StartByteRpt = 4 + 1                             # Four for time, one payload ID  
    PIP0StopByteRpt = PIP0StartByteRpt + sweepSamples*2   # Number of samples, two bytes each
    PIP1StopByteRpt = PIP0StopByteRpt + sweepSamples*2      # Number of samples, two bytes each
    
    for i in sweeps:
        if len(i) == numSweepBytes:
            sweepTime.append(combine4(i[3], i[2], i[1], i[0]))
            payloadID.append(i[4])
            tempSweep = []
            for byte in range(PIP0StartByte,PIP0StopByte,2):
                allSweepsPIP0.append(combine2(i[byte+1], i[byte]))
                tempSweep.append(combine2(i[byte+1], i[byte]))
            individualSweepsPIP0.append(tempSweep)
            tempSweep = []
            for byte in range(PIP0StopByte,PIP1StopByte,2):
                allSweepsPIP1.append(combine2(i[byte+1], i[byte]))
                tempSweep.append(combine2(i[byte+1], i[byte]))
            individualSweepsPIP1.append(tempSweep)

    for i in sweepsRpt:
        if len(i) == numSweepBytes:
            sweepTimeRpt.append(combine4(i[3], i[2], i[1], i[0]))
            tempSweepRpt = []
            for byte in range(PIP0StartByteRpt,PIP0StopByteRpt,2):
                allSweepsPIP0Rpt.append(combine2(i[byte+1], i[byte]))
                tempSweepRpt.append(combine2(i[byte+1], i[byte]))
            individualSweepsPIP0Rpt.append(tempSweepRpt)
            tempSweepRpt = []
            for byte in range(PIP0StopByteRpt,PIP1StopByteRpt,2):
                allSweepsPIP1Rpt.append(combine2(i[byte+1], i[byte]))
                tempSweepRpt.append(combine2(i[byte+1], i[byte]))
            individualSweepsPIP1Rpt.append(tempSweepRpt)
            
    interruptTime = []        
    for i in interrupt:
        if len(i) == numInterruptBytes:
            interruptTime.append(combine4(i[3], i[2], i[1], i[0]))
                       
    payloadMatch = (len(set(payloadID)) == 1)
    if payloadMatch:
        print("Payload ID's match. This was payload #%s." %payloadID[0])
    else:
        print("Payload ID's don't match. Something went wrong...")
        
    sweepTime = np.array(sweepTime, dtype='uint32')
    individualSweepsPIP0 = np.array(individualSweepsPIP0, dtype='int16')
    individualSweepsPIP1 = np.array(individualSweepsPIP1, dtype='int16')
    payload.sweeps.time = sweepTime
    payload.sweeps.pip0 = individualSweepsPIP0
    payload.sweeps.pip1 = individualSweepsPIP1
    
    sweepTimeRpt = np.array(sweepTimeRpt, dtype='uint32')
    individualSweepsPIP0Rpt = np.array(individualSweepsPIP0Rpt, dtype='int16')
    individualSweepsPIP1Rpt = np.array(individualSweepsPIP1Rpt, dtype='int16')
    payload.sweeps.timeRpt = sweepTimeRpt
    payload.sweeps.pip0Rpt = individualSweepsPIP0Rpt
    payload.sweeps.pip1Rpt = individualSweepsPIP1Rpt
# Out:
# Num IMU Messages: 22282
# Num Sweep Messages: 22243
# Num IMU Messages (buffer): 22289
# Num Sweep Messages (buffer): 22271
# Num interrupt messages: 23
# Payload ID's don't match. Something went wrong...

# %%
################################## Forming and Scaling Data ##################################### 

sweepSize = 28
sweepStepDt = 0.02 / sweepSize

# Define as None for no limits
timeMin = None # 485 produces better plots than 480
timeMax = None

# Set by the time limits automatically
timesToSkip = 30 # To impove the quality of sample numbering selection
IMUSampleMin = None
IMUSampleMax = None
SweepSampleMin = None
SweepSampleMax = None

for payload in payloads:
    # Extract data from each set, cast into arrays
    aScale = 4*9.8; mScale = 1.; gScale = 2000./360
    
    imuTime = np.array(payload.imu.time)/1.E6;
    sweepTime = np.array(payload.sweeps.time)/1.E6
    
    imuTimeRpt = np.array(payload.imu.timeRpt)/1.E6;
    sweepTimeRpt = np.array(payload.sweeps.timeRpt)/1.E6
    
    # Figure out what the sample bounds should be
    if timeMin:
        IMUSampleMin = np.where(imuTime>=timeMin)[0][timesToSkip]
        IMUSampleMax = np.where(imuTime<=timeMax)[0][-1 * timesToSkip]
        SweepSampleMin = np.where(sweepTime>=timeMin)[0][timesToSkip]
        SweepSampleMax = np.where(sweepTime<=timeMax)[0][-1 * timesToSkip]
    imuTime = imuTime[IMUSampleMin:IMUSampleMax]
    sweepTime = sweepTime[SweepSampleMin:SweepSampleMax]
    
    ############################################################
    ##Bringing in from parse_erpabob-2 to use for lineplots
    # Flatten out sweepSampleTime 
    sweepSampleTime = []
    for t in sweepTime:
        for n in range(0, sweepSize):
            sweepSampleTime.append(t+sweepStepDt*n)
    sweepSampleTime = np.array(sweepSampleTime)
    sweepSampleTime = sweepSampleTime - T0_offset
    
    pip0 = np.array(payload.sweeps.pip0)*5./2**14
    pip1 = np.array(payload.sweeps.pip1)*5./2**14
    pip1L = pip1.flatten();
    pip0L = pip0.flatten();
    
    sweepSampleTimeRpt = []
    for t in sweepTimeRpt: 
        for n in range(0, sweepSize):
            sweepSampleTimeRpt.append(t+sweepStepDt*n)
    sweepSampleTimeRpt = np.array(sweepSampleTimeRpt)
    sweepSampleTimeRpt = sweepSampleTimeRpt - T0_offset
    
    pip0Rpt = np.array(payload.sweeps.pip0Rpt)*5./2**14
    pip1Rpt = np.array(payload.sweeps.pip1Rpt)*5./2**14
    pip0RptL = pip0Rpt.flatten();
    pip1RptL = pip1Rpt.flatten();
    #SweepSampleMin = SweepSampleMin * sweepSize # Scale up sizing
    #SweepSampleMax = SweepSampleMax * sweepSize
    ############################################################
     
    # Make everything an array
    interruptArray = (np.array(interruptTime)/10**6)+interruptOffset
    
    temp = payload.imu.temp[IMUSampleMin:IMUSampleMax];
    ax = np.array(payload.imu.ax[IMUSampleMin:IMUSampleMax])*aScale/2**15
    ay = np.array(payload.imu.ay[IMUSampleMin:IMUSampleMax])*aScale/2**15
    az = np.array(payload.imu.az[IMUSampleMin:IMUSampleMax])*aScale/2**15
    mx = np.array(payload.imu.mx[IMUSampleMin:IMUSampleMax])*mScale/2**15
    my = np.array(payload.imu.my[IMUSampleMin:IMUSampleMax])*mScale/2**15
    mz = np.array(payload.imu.mz[IMUSampleMin:IMUSampleMax])*mScale/2**15
    gx = np.array(payload.imu.gx[IMUSampleMin:IMUSampleMax])*gScale/2**15
    gy = np.array(payload.imu.gy[IMUSampleMin:IMUSampleMax])*gScale/2**15
    gz = np.array(payload.imu.gz[IMUSampleMin:IMUSampleMax])*gScale/2**15
    shieldID = payload.shieldID
    pip0 = np.array(payload.sweeps.pip0)*5./2**14
    pip1 = np.array(payload.sweeps.pip1)*5./2**14
    
    tempRpt = payload.imu.tempRpt[IMUSampleMin:IMUSampleMax];
    axRpt = np.array(payload.imu.axRpt[IMUSampleMin:IMUSampleMax])*aScale/2**15
    ayRpt = np.array(payload.imu.ayRpt[IMUSampleMin:IMUSampleMax])*aScale/2**15
    azRpt = np.array(payload.imu.azRpt[IMUSampleMin:IMUSampleMax])*aScale/2**15
    mxRpt = np.array(payload.imu.mxRpt[IMUSampleMin:IMUSampleMax])*mScale/2**15
    myRpt = np.array(payload.imu.myRpt[IMUSampleMin:IMUSampleMax])*mScale/2**15
    mzRpt = np.array(payload.imu.mzRpt[IMUSampleMin:IMUSampleMax])*mScale/2**15
    gxRpt = np.array(payload.imu.gxRpt[IMUSampleMin:IMUSampleMax])*gScale/2**15
    gyRpt = np.array(payload.imu.gyRpt[IMUSampleMin:IMUSampleMax])*gScale/2**15
    gzRpt = np.array(payload.imu.gzRpt[IMUSampleMin:IMUSampleMax])*gScale/2**15
    pip0Rpt = np.array(payload.sweeps.pip0Rpt)*5./2**14
    pip1Rpt = np.array(payload.sweeps.pip1Rpt)*5./2**14
    
    print("Data Scaled")
# Out:
# Data Scaled

# %%
# Changes screen voltage to nA

highV2I = 1.0/(320.0E-3)
lowV2I = 1.0/(40.0E-3)

pip0nA = (pip0-1)*lowV2I
pip1nA = (pip1-1)*highV2I
pip0RptnA = (pip0Rpt-1)*lowV2I
pip1RptnA = (pip1Rpt-1)*highV2I

# %% [markdown]
# <a id="saveFrickle"></a>
# ### Save Parsed Data to Frickle file

# %%
# # Make/Save Frickle File as hdf5 file
# import h5py 
# import os
# frickle_path = './'
# tref_type='Reg'; flightData=False
# fklfname = os.path.join(frickle_path, "%sTime_ParsedData_Frickle-%s.hdf5" % (tref_type.capitalize(), file_name.partition(".")[0]))
# with h5py.File(fklfname, "w") as h5dct:
#     h5dct['parent_file'] = dataFile; #h5dct['DeltInx']=DeltInx
#     h5dct['shieldID']=shieldID;
#     h5dct['buff_data']=True
# #     dct['pipVoffset']
#     dct = h5dct.create_group('Original')
#     dct['imuTime']=imuTime; dct['temp']=temp; dct['ax']=ax; dct['ay']=ay; dct['az']=az
#     dct['gx']=gx; dct['gy']=gy; dct['gz']=gz; dct['mx']=mx; dct['my']=my; dct['mz']=mz
#     dct['sweepTime']=sweepTime; dct['sweepTimeLn']=sweepSampleTime; dct['sweepSize']=sweepSize; dct['sweepStepDt']=sweepStepDt
#     dct['pip0nA']=pip0nA; dct['pip1nA']=pip1nA; dct['pip0VLn']=pip0L; dct['pip1VLn']=pip1L
#     dct['pip0V2I']=pip0V2I; dct['pip1V2I']=pip1V2I
    
#     dctRpt = h5dct.create_group('Repeat')
#     dctRpt['imuTime']=imuTimeRpt; dctRpt['temp']=tempRpt; dctRpt['ax']=axRpt; dctRpt['ay']=ayRpt; dctRpt['az']=azRpt
#     dctRpt['gx']=gxRpt; dctRpt['gy']=gyRpt; dctRpt['gz']=gzRpt; dctRpt['mx']=mxRpt; dctRpt['my']=myRpt; dctRpt['mz']=mzRpt
#     dctRpt['sweepTime']=sweepTimeRpt; dctRpt['sweepTimeLn']=sweepSampleTimeRpt; dctRpt['sweepSize']=sweepSize; dctRpt['sweepStepDt']=sweepStepDt
#     dctRpt['pip0nA']=pip0RptnA; dctRpt['pip1nA']=pip1RptnA; dctRpt['pip0VLn']=pip0RptL; dctRpt['pip1VLn']=pip1RptL
#     dctRpt['pip0V2I']=pip0V2I; dct['pip1V2I']=pip1V2I
    
#     if flightData: h5dct['shield_T0'] = T0_dct[shieldID]
#     else: h5dct['shield_T0'] = 0
#     if tref_type.capitalize=='Flight': h5dct['applied_T0'] = True
#     else: h5dct['applied_T0'] = False
# del fklfname, h5dct

# %% [markdown]
# <a id="plotting"></a>
# ## Plotting Section
# Options:
# * [Plot Data Over Time](#plotting)
# * [Plot Data in Realtime Parser Format](#plot_byIdx)
#
# ### Plot Data Over Time

# %%
if plottype == "original":
    version = 'Original'
    imuPlot = imuTime.tolist()
    axPlot = ax
    ayPlot = ay
    azPlot = az
    gxPlot = gx
    gyPlot = gy
    gzPlot = gz
    mxPlot = mx
    myPlot = my
    mzPlot = mz
    tempPlot = temp
    sweepPlot = sweepTime.tolist()
    pip0Plot = pip0nA
    pip1Plot = pip1nA 
    
    pip0LPlot = pip0L
    pip1LPlot = pip1L
    sweepTimeLPlot = sweepSampleTime
    
elif plottype == 'repeat':
    version = 'Repeat'
    imuPlot = imuListRpt
    axPlot = axRpt
    ayPlot = ayRpt
    azPlot = azRpt
    gxPlot = gxRpt
    gyPlot = gyRpt
    gzPlot = gzRpt
    mxPlot = mxRpt
    myPlot = myRpt
    mzPlot = mzRpt
    tempPlot = tempRpt
    sweepPlot = sweepListRpt
    pip0Plot = pip0RptnA
    pip1Plot = pip1RptnA
    
    pip0LPlot = pip0RptL
    pip1LPlot = pip1RptL
    sweepTimeLPlot = sweepSampleTimeRpt

## Added by Magda Moses 5/5/2023
magfullPlot = np.sqrt(mxPlot**2+myPlot**2+mzPlot**2)
if 0<len(interruptArray): interruptValue = True
else: interruptValue=False

# %%
## Modify PIP Lineplots' and colorplots' x-axis limits and set PIP colorplots' colorbar limits
# Default: 
xlims = None
pip0LnLims = None; pip1LnLims=pip0LnLims
cplt_kwargs={'pip0': {}, 'pip1':{}}

#
# xlims = [460, 600]
pip0LnLims=[0, 5]; pip1LnLims=[0, 5]
# pip0LnLims=[1, 1.25]; pip1LnLims=[0.75, 1.25]
# xlims = [665, 665.5]

# cplt_kwargs={'pip0': {}, 'pip1':{}}
# # cplt_kwargs={'pip0': {'vmin':0, 'vmax':5}, 'pip1':{'vmin':1, 'vmax':8}}
# cplt_kwargs={'pip0': {'vmin':-2, 'vmax':10}, 'pip1':{'vmin':-2, 'vmax':10}}

# %%
matplotlib.use('nbagg')
import matplotlib.cm as cm
import scipy.signal as sig
from scipy.interpolate import interp1d
from scipy.io import savemat, loadmat
from __future__ import division

dots = True

gs_left = plt.GridSpec(6, 2,  hspace=0.7)

# Set up dots or not more cleanly
line_style = '-'
if dots:
    line_style = '.'

markersize = 1
if plt.fignum_exists(1): plt.close(1)
fig = plt.figure(1, figsize=(10, 7.5))

# Accel
ax1 = fig.add_subplot(gs_left[0,0])
plt.plot(imuPlot, axPlot, line_style, markersize=markersize) 
plt.plot(imuPlot, ayPlot, line_style, markersize=markersize)  
plt.plot(imuPlot, azPlot, line_style, markersize=markersize) 
plt.ylabel("Accel (m/s$^2$)")
#plt.ylim([-2, 2])
#plt.xlim([75, 100])
plt.xticks(visible=True)
plt.xlabel("Time (s)")
print ("1 Done")

# Mag
fig.add_subplot(gs_left[1,0],sharex=ax1)
plt.plot(imuPlot, mxPlot, line_style, markersize=markersize) 
plt.plot(imuPlot, myPlot, line_style, markersize=markersize)  
plt.plot(imuPlot, mzPlot, line_style, markersize=markersize) 
plt.plot(imuPlot, magfullPlot, line_style, markersize=markersize, color='black')
#plt.ylim([-0.2, 0.25])
plt.ylabel("Mag (Gauss)") 
#plt.xlim([75, 100])
plt.xticks(visible=True)
plt.xlabel("Time (s)")
print ("2 Done")

# Gyro
fig.add_subplot(gs_left[2,0],sharex=ax1)
plt.plot(imuPlot, gxPlot, line_style, markersize=markersize) 
plt.plot(imuPlot, gyPlot, line_style, markersize=markersize)  
plt.plot(imuPlot, gzPlot, line_style, markersize=markersize) 
plt.ylabel("Gyro (Hz)")
#plt.ylim([-0.5, 0.5])  
#plt.xlim([75, 100])
plt.xticks(visible=True)
plt.xlabel("Time (s)")
print ("3 Done")

# First PIP (line)
axP = fig.add_subplot(gs_left[3,0], sharex=ax1)
plt.plot(sweepTimeLPlot, pip0LPlot, line_style, markersize=markersize, color='blue')
plt.ylabel("PIP0 (V)")
#plt.ylim([0.8, 1.2])
if pip0LnLims is not None: plt.ylim(pip0LnLims)
if xlims is not None: plt.xlim(xlims)
print("4 Done")

# Second PIP (line)
fig.add_subplot(gs_left[4,0], sharex=axP)
plt.plot(sweepTimeLPlot, pip1LPlot, line_style, markersize=markersize, color='blue')
#plt.ylim([0.8, 1.2])
if xlims is not None: plt.xlim(xlims)
if pip1LnLims is not None: plt.ylim(pip1LnLims)
plt.ylabel("PIP1 (V)")
print("5 Done")

# Cadence (sweep on top)
axis2 = fig.add_subplot(gs_left[5,0])
plt.plot(np.diff(imuPlot)*1E3, line_style, color='blue', markersize=markersize)
plt.plot(np.diff(sweepPlot)*1E3, line_style, color='red', markersize=markersize)
#plt.ylim([20,50])
#plt.xlim([2000,4000])
plt.ylabel("Cadences (ms)\n IMU-Blue\n Sweep-Red")
plt.xlabel("Index")
print ("6 Done")

# Cadence (imu on top)
fig.add_subplot(gs_left[5,1], sharex=axis2, sharey=axis2)
plt.plot(np.diff(sweepPlot)*1E3, line_style, color='red', markersize=markersize)
plt.plot(np.diff(imuPlot)*1E3, line_style, color='blue', markersize=markersize)
#plt.ylim([20,50])
#plt.xlim([2000,4000])
plt.xlabel("Index")
print ("7 Done")

# **Plot sweep time vs sweep data (Color plots)**

# commands to reorient pip array to match with other axes
pip0_rot = np.rot90(pip0Plot, k=1, axes=(0, 1))
pip1_rot = np.rot90(pip1Plot, k=1, axes=(0, 1))

sweep_voltage = np.linspace(0,5,28)

line_style = '-'

ax1 = plt.subplot2grid((5,2),(0,1),rowspan = 2, sharex=axP)
plt.pcolormesh(sweepPlot, sweep_voltage, pip0_rot, cmap='plasma', **cplt_kwargs['pip0'])
if xlims is not None: plt.xlim(xlims)
ax1.set_xlabel("Flight Time (s)")
ax1.set_ylabel("Screen Bias (V)")
cb = plt.colorbar(pad = 0.2)
cb.set_label("PIP0 (nA)")
print ("8 Done")

ax1 = plt.subplot2grid((5,2),(2,1),rowspan = 2, sharex=ax1)
plt.pcolormesh(sweepPlot, sweep_voltage, pip1_rot, cmap='plasma', **cplt_kwargs['pip1'])
if xlims is not None: plt.xlim(xlims)
ax1.set_xlabel("Flight Time (s)")
ax1.set_ylabel("Screen Bias (V)")
cb = plt.colorbar(pad = 0.2)
cb.set_label("PIP1 (nA)")
print ("9 Done")
        
# Adjust figure
fig.subplots_adjust(right=.90)
fig.subplots_adjust(left=0.10)
fig.subplots_adjust(top=0.90)
fig.subplots_adjust(bottom=0.10)
fig.subplots_adjust(hspace=0.75)

if interruptValue and len(interruptArray) > 100:
    interruptNum = str(interruptArray[100]-T0_offset) + " seconds"
else:
    interruptNum = "None"
# T0_offset = 577.271
plt.suptitle(file_name+": Data from Shield %s (Version: %s)\n Interrupt Time: %s \n(modified %ss for interrupt offset, %s for flight time)" 
             %(shieldID, version, interruptNum, interruptOffset, T0_offset), fontweight='bold')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# 7 Done
# /var/folders/78/s5whl1wn7cq4ydg9w06dxc7h0000gn/T/ipykernel_45881/597065265.py:106: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(sweepPlot, sweep_voltage, pip0_rot, cmap='plasma', **cplt_kwargs['pip0'])
# /var/folders/78/s5whl1wn7cq4ydg9w06dxc7h0000gn/T/ipykernel_45881/597065265.py:115: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(sweepPlot, sweep_voltage, pip1_rot, cmap='plasma', **cplt_kwargs['pip1'])
# 8 Done
# 9 Done

# %%
imuTime
fig = plt.figure(3) 
ax1 = fig.add_subplot(111)
ax1.plot(imuTime, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <a id="plot_byIdx"></a>
# ### Plot Data in Realtime Parser Format

# %%
if plottype == "original":
    version = 'Original'
#     imuPlot = imuTime.tolist()
#     imuDct = {'imuPlot': imuTime, \
    imuTmp = {'axPlot': ax, 'ayPlot': ay, 'azPlot': az,\
              'gxPlot': gx, 'gyPlot': gy, 'gzPlot': gz,\
              'mxPlot': mx, 'myPlot': my, 'mzPlot': mz}
#     axPlt = ax
#     ayPlt = ay
#     azPlt = az
#     gxPlt = gx
#     gyPlt = gy
#     gzPlt = gz
#     mxPlt = mx
#     myPlt = my
#     mzPlt = mz

    sweepPlot = sweepTime.tolist()
    pip0Plot = pip0nA
    pip1Plot = pip1nA 
    
    pip0LPlot = pip0L
    pip1LPlot = pip1L
    sweepLPlot = np.arange(0, len(sweepSampleTime), 1)
    
elif plottype == 'repeat':
    version = 'Repeat'
#     imuPlot = imuListRpt
#     imuDct = {'imuPlot': imuListRpt, \
    imuTmp = {'axPlot': axRpt, 'ayPlot': ayRpt, 'azPlot': azRpt,\
          'gxPlot': gxRpt, 'gyPlot': gyRpt, 'gzPlot': gzRpt,\
          'mxPlot': mxRpt, 'myPlot': myRpt, 'mzPlot': mzRpt}
#     axPlt = axRpt
#     ayPlt = ayRpt
#     azPlt = azRpt
#     gxPlt = gxRpt
#     gyPlt = gyRpt
#     gzPlt = gzRpt
#     mxPlt = mxRpt
#     myPlt = myRpt
#     mzPlt = mzRpt
    
    sweepPlot = sweepListRpt
    pip0Plot = pip0RptnA
    pip1Plot = pip1RptnA
    
    pip0LPlot = pip0RptL
    pip1LPlot = pip1RptL
    sweepLPlot = np.arange(0, len(sweepSampleTimeRpt),1)



axPlot=[]; ayPlot=[]; azPlot=[]
gxPlot=[]; gyPlot=[]; gzPlot=[]
mxPlot=[]; myPlot=[]; mzPlot=[]
imuDct = {key: [] for key in list(imuTmp.keys())}
imuDct['imuPlot'] = []
for idx in range(0, len(imuTime)): 
    for key in list(imuDct.keys()): 
        if key != 'imuPlot': imuDct[key].extend([imuTmp[key][idx]]*28)
        else: imuDct['imuPlot'].extend(np.arange(idx*28, idx*28+28, 1).tolist())
#     imuDct['imuPlot'].append(idx)
for key in list(imuDct.keys()): imuDct[key] = np.array(imuDct[key])

## Added by Magda Moses 5/5/2023
magfullPlot = np.sqrt(imuDct['mxPlot']**2+imuDct['myPlot']**2+imuDct['mzPlot']**2)
if 0<len(interruptArray): interruptValue = True
else: interruptValue=False

# %%
print(np.all(imuDct['imuPlot']==sweepLPlot))
print(len(sweepLPlot))
print(len(imuDct['imuPlot']))
# np.where(sweepLPlot)
# Out:
# False
# 622804
# 623896
# /var/folders/78/s5whl1wn7cq4ydg9w06dxc7h0000gn/T/ipykernel_44996/2095033077.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   print(np.all(imuDct['imuPlot']==sweepLPlot))

# %%
## Modify PIP Lineplots' and colorplots' x-axis limits and set PIP colorplots' colorbar limits
# Default: 
xlims = None
pip0LnLims = None; pip1LnLims=pip0LnLims
cplt_kwargs={'pip0': {}, 'pip1':{}}

#
# xlims = [460, 600]
pip0LnLims=[0, 5]; pip1LnLims=[0, 5]
# pip0LnLims=[1, 1.25]; pip1LnLims=[0.75, 1.25]
# xlims = [665, 665.5]

# cplt_kwargs={'pip0': {}, 'pip1':{}}
# # cplt_kwargs={'pip0': {'vmin':0, 'vmax':5}, 'pip1':{'vmin':1, 'vmax':8}}
# cplt_kwargs={'pip0': {'vmin':-2, 'vmax':10}, 'pip1':{'vmin':-2, 'vmax':10}}

# %%
matplotlib.use('nbagg')
import matplotlib.cm as cm
import scipy.signal as sig
from scipy.interpolate import interp1d
from scipy.io import savemat, loadmat
from __future__ import division

dots = True

gs_left = plt.GridSpec(6, 2,  hspace=0.7)

# Set up dots or not more cleanly
line_style = '-'
if dots:
    line_style = '.'

markersize = 1
if plt.fignum_exists(2): plt.close(2)
fig = plt.figure(2, figsize=(10, 7.5))

# Accel
ax1 = fig.add_subplot(gs_left[0,0])
plt.plot(imuDct['imuPlot'], imuDct['axPlot'], line_style, markersize=markersize) 
plt.plot(imuDct['imuPlot'], imuDct['ayPlot'], line_style, markersize=markersize)  
plt.plot(imuDct['imuPlot'], imuDct['azPlot'], line_style, markersize=markersize) 
plt.ylabel("Accel (m/s$^2$)")
#plt.ylim([-2, 2])
#plt.xlim([75, 100])
plt.xticks(visible=True)
plt.xlabel("Time (s)")
print ("1 Done")

# Mag
fig.add_subplot(gs_left[1,0],sharex=ax1)
plt.plot(imuDct['imuPlot'], imuDct['mxPlot'], line_style, markersize=markersize) 
plt.plot(imuDct['imuPlot'], imuDct['myPlot'], line_style, markersize=markersize)  
plt.plot(imuDct['imuPlot'], imuDct['mzPlot'], line_style, markersize=markersize) 
plt.plot(imuDct['imuPlot'], magfullPlot, line_style, markersize=markersize, color='black')
#plt.ylim([-0.2, 0.25])
plt.ylabel("Mag (Gauss)") 
#plt.xlim([75, 100])
plt.xticks(visible=True)
plt.xlabel("Time (s)")
print ("2 Done")

# Gyro
fig.add_subplot(gs_left[2,0],sharex=ax1)
plt.plot(imuDct['imuPlot'], imuDct['gxPlot'], line_style, markersize=markersize) 
plt.plot(imuDct['imuPlot'], imuDct['gyPlot'], line_style, markersize=markersize)  
plt.plot(imuDct['imuPlot'], imuDct['gzPlot'], line_style, markersize=markersize) 
plt.ylabel("Gyro (Hz)")
#plt.ylim([-0.5, 0.5])  
#plt.xlim([75, 100])
plt.xticks(visible=True)
plt.xlabel("Time (s)")
print ("3 Done")

# First PIP (line)
axP = fig.add_subplot(gs_left[3,0], sharex=ax1)
# plt.plot(sweepTimeLPlot, pip0LPlot, line_style, markersize=markersize, color='blue')
plt.plot(sweepLPlot, pip0LPlot, line_style, markersize=markersize, color='blue')
plt.ylabel("PIP0 (V)")
#plt.ylim([0.8, 1.2])
if pip0LnLims is not None: plt.ylim(pip0LnLims)
if xlims is not None: plt.xlim(xlims)
print("4 Done")

# Second PIP (line)
fig.add_subplot(gs_left[4,0], sharex=axP)
# plt.plot(sweepTimeLPlot, pip1LPlot, line_style, markersize=markersize, color='blue')
plt.plot(sweepLPlot, pip1LPlot, line_style, markersize=markersize, color='blue')
#plt.ylim([0.8, 1.2])
if xlims is not None: plt.xlim(xlims)
if pip1LnLims is not None: plt.ylim(pip1LnLims)
plt.ylabel("PIP1 (V)")
print("5 Done")

# Cadence (sweep on top)
axis2 = fig.add_subplot(gs_left[5,0])
plt.plot(np.diff(imuDct['imuPlot'])*1E3, line_style, color='blue', markersize=markersize)
plt.plot(np.diff(sweepPlot)*1E3, line_style, color='red', markersize=markersize)
#plt.ylim([20,50])
#plt.xlim([2000,4000])
plt.ylabel("Cadences (ms)\n IMU-Blue\n Sweep-Red")
plt.xlabel("Index")
print ("6 Done")

# Cadence (imu on top)
fig.add_subplot(gs_left[5,1], sharex=axis2, sharey=axis2)
plt.plot(np.diff(sweepPlot)*1E3, line_style, color='red', markersize=markersize)
plt.plot(np.diff(imuDct['imuPlot'])*1E3, line_style, color='blue', markersize=markersize)
#plt.ylim([20,50])
#plt.xlim([2000,4000])
plt.xlabel("Index")
print ("7 Done")

# **Plot sweep time vs sweep data (Color plots)**

# commands to reorient pip array to match with other axes
pip0_rot = np.rot90(pip0Plot, k=1, axes=(0, 1))
pip1_rot = np.rot90(pip1Plot, k=1, axes=(0, 1))

sweep_voltage = np.linspace(0,5,28)

line_style = '-'

ax1 = plt.subplot2grid((5,2),(0,1),rowspan = 2)
plt.pcolormesh(sweepPlot, sweep_voltage, pip0_rot, cmap='plasma', **cplt_kwargs['pip0'])
if xlims is not None: plt.xlim(xlims)
ax1.set_xlabel("Flight Time (s)")
ax1.set_ylabel("Screen Bias (V)")
cb = plt.colorbar(pad = 0.2)
cb.set_label("PIP0 (nA)")
print ("8 Done")

ax1 = plt.subplot2grid((5,2),(2,1),rowspan = 2, sharex=ax1)
plt.pcolormesh(sweepPlot, sweep_voltage, pip1_rot, cmap='plasma', **cplt_kwargs['pip1'])
if xlims is not None: plt.xlim(xlims)
ax1.set_xlabel("Flight Time (s)")
ax1.set_ylabel("Screen Bias (V)")
cb = plt.colorbar(pad = 0.2)
cb.set_label("PIP1 (nA)")
print ("9 Done")
        
# Adjust figure
fig.subplots_adjust(right=.90)
fig.subplots_adjust(left=0.10)
fig.subplots_adjust(top=0.90)
fig.subplots_adjust(bottom=0.10)
fig.subplots_adjust(hspace=0.75)

if interruptValue and len(interruptArray) > 100:
    interruptNum = str(interruptArray[100]-T0_offset) + " seconds"
else:
    interruptNum = "None"
# T0_offset = 577.271
plt.suptitle(file_name+": Data from Shield %s (Version: %s)\n Interrupt Time: %s \n(modified %ss for interrupt offset, %s for flight time)" 
             %(shieldID, version, interruptNum, interruptOffset, T0_offset), fontweight='bold')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# 1 Done
# 2 Done
# 3 Done
# 4 Done
# 5 Done
# 6 Done
# 7 Done
# 8 Done
# /var/folders/78/s5whl1wn7cq4ydg9w06dxc7h0000gn/T/ipykernel_44996/1090188508.py:108: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(sweepPlot, sweep_voltage, pip0_rot, cmap='plasma', **cplt_kwargs['pip0'])
# /var/folders/78/s5whl1wn7cq4ydg9w06dxc7h0000gn/T/ipykernel_44996/1090188508.py:117: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   plt.pcolormesh(sweepPlot, sweep_voltage, pip1_rot, cmap='plasma', **cplt_kwargs['pip1'])
# 9 Done

# %%
sweepTime
# Out:
# array([ 711.201304,  472.540288,  711.267904, ..., 1271.9955  ,
#        1272.0177  , 1272.039904])

# %%
## %% For ADC Calibrations %%
# Select PIP, step voltage difference and offset from start/end of step
pipLData = pip0LPlot.copy() # For Checking PIP 0 
# pipLData = pip1LPlot.copy() # For Checking PIP 1
dV = .2 # step voltage difference 
dStep = 10 # Offset (in # of points) from start/end of step

diff = np.diff(pipLData)
locs = np.where(dV<=np.abs(diff))[0]
print('Times %s\n' % (sweepTimeLPlot[locs])) 
for sloc, eloc in zip(locs[0:-1], locs[1:]): 
    avg = np.mean(pipLData[sloc+dStep:eloc-dStep])
    print('Times %.2f-%.2fs: Average %.3f V' % (sweepTimeLPlot[sloc+dStep], sweepTimeLPlot[eloc-dStep-1], avg))
# Out:
# Times [ 25.42477143  25.42548571  25.4262     ... 589.54262814 589.54334243
#  589.54405671]
#
# Times 25.43-25.42s: Average nan V
# Times 25.43-25.42s: Average nan V
# Times 25.43-25.42s: Average nan V
# Times 25.43-25.43s: Average nan V
# Times 25.83-27.08s: Average 1.017 V
# Times 27.10-27.08s: Average nan V
# Times 27.10-27.08s: Average nan V
# Times 27.10-27.08s: Average nan V
# Times 27.10-27.08s: Average nan V
# Times 27.10-27.08s: Average nan V
# Times 27.10-27.09s: Average nan V
# Times 27.10-27.09s: Average nan V
# Times 27.10-27.09s: Average nan V
# Times 27.10-27.09s: Average nan V
# Times 27.10-27.09s: Average nan V
# Times 27.10-27.09s: Average nan V
# Times 27.10-27.09s: Average nan V
# Times 27.11-27.09s: Average nan V
# Times 27.71-27.09s: Average nan V
# Times 27.71-27.09s: Average nan V
# Times 27.71-27.09s: Average nan V
# Times 27.71-27.09s: Average nan V
# Times 27.71-27.09s: Average nan V
# Times 27.71-27.10s: Average nan V
# Times 27.71-27.10s: Average nan V
# Times 27.71-27.10s: Average nan V
# Times 27.71-27.10s: Average nan V
# Times 27.71-395.82s: Average 1.018 V
# Times 2049.14-2049.14s: Average 2.940 V
# Times 395.83-2049.14s: Average nan V
# Times 395.83-2049.14s: Average nan V
# Times 395.83-2049.14s: Average nan V
# Times 395.83-2049.15s: Average nan V
# Times 395.83-397.08s: Average 1.016 V
# Times 1881.36-1881.36s: Average nan V
# Times 397.09-1881.36s: Average nan V
# Times 397.09-1881.36s: Average nan V
# Times 397.10-1881.36s: Average nan V
# Times 397.10-1881.36s: Average nan V
# Times 397.10-1881.36s: Average nan V
# Times 397.10-1881.36s: Average nan V
# Times 397.10-1881.36s: Average nan V
# Times 397.10-1881.37s: Average nan V
# Times 397.10-1881.37s: Average nan V
# Times 397.10-398.88s: Average 1.016 V
# Times 3659.79-398.89s: Average nan V
# Times 3659.80-398.89s: Average nan V
# Times 3659.80-398.89s: Average nan V
# Times 3659.80-398.89s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 398.89-3659.79s: Average nan V
# Times 398.89-3659.79s: Average nan V
# Times 398.89-3659.79s: Average nan V
# Times 398.90-3659.80s: Average nan V
# Times 398.90-3659.80s: Average nan V
# Times 398.90-3659.80s: Average nan V
# Times 398.90-3659.80s: Average nan V
# Times 398.90-399.24s: Average 1.016 V
# Times 505.69-399.24s: Average nan V
# Times 505.70-399.24s: Average nan V
# Times 505.70-399.24s: Average nan V
# Times 505.70-399.24s: Average nan V
# Times 505.70-399.24s: Average nan V
# Times 505.70-399.24s: Average nan V
# Times 505.70-399.24s: Average nan V
# Times 505.70-505.69s: Average nan V
# Times 505.70-505.69s: Average nan V
# Times 505.70-505.69s: Average nan V
# Times 505.70-505.69s: Average nan V
# Times 505.71-505.69s: Average nan V
# Times 399.25-505.69s: Average nan V
# Times 399.25-505.69s: Average nan V
# Times 399.25-505.69s: Average nan V
# Times 399.25-505.69s: Average nan V
# Times 399.25-505.69s: Average nan V
# Times 399.25-505.70s: Average nan V
# Times 399.25-505.70s: Average nan V
# Times 399.25-505.70s: Average nan V
# Times 399.25-505.70s: Average nan V
# Times 399.25-399.57s: Average 1.016 V
# Times 2183.45-399.57s: Average nan V
# Times 2183.45-399.57s: Average nan V
# Times 2183.45-399.57s: Average nan V
# Times 2183.46-399.57s: Average nan V
# Times 2183.46-399.57s: Average nan V
# Times 2183.46-399.57s: Average nan V
# Times 2183.46-399.57s: Average nan V
# Times 2183.46-399.58s: Average nan V
# Times 2183.46-399.58s: Average nan V
# Times 2183.46-399.58s: Average nan V
# Times 2183.46-2183.45s: Average nan V
# Times 2183.46-2183.45s: Average nan V
# Times 2183.46-2183.45s: Average nan V
# Times 2183.46-2183.45s: Average nan V
# Times 2183.47-2183.45s: Average nan V
# Times 399.58-2183.45s: Average nan V
# Times 399.58-2183.45s: Average nan V
# Times 399.58-2183.45s: Average nan V
# Times 399.58-2183.45s: Average nan V
# Times 399.58-2183.46s: Average nan V
# Times 399.59-400.12s: Average 1.016 V
# Times 589.56-400.12s: Average nan V
# Times 589.56-400.13s: Average nan V
# Times 589.56-400.13s: Average nan V
# Times 589.56-400.13s: Average nan V
# Times 589.56-400.13s: Average nan V
# Times 589.56-400.13s: Average nan V
# Times 589.56-400.13s: Average nan V
# Times 589.56-400.13s: Average nan V
# Times 589.57-589.55s: Average nan V
# Times 589.57-589.55s: Average nan V
# Times 589.57-589.55s: Average nan V
# Times 589.57-589.56s: Average nan V
# Times 589.57-589.56s: Average nan V
# Times 589.57-589.56s: Average nan V
# Times 589.57-589.56s: Average nan V
# Times 589.57-589.56s: Average nan V
# Times 400.13-589.56s: Average nan V
# Times 400.14-589.56s: Average nan V
# Times 400.14-589.56s: Average nan V
# Times 400.14-589.56s: Average nan V
# Times 400.14-589.56s: Average nan V
# Times 400.14-589.56s: Average nan V
# Times 400.14-400.66s: Average 1.016 V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-400.66s: Average nan V
# Times 3810.79-3810.78s: Average nan V
# Times 3810.79-3810.78s: Average nan V
# Times 3810.80-3810.78s: Average nan V
# Times 3810.80-3810.78s: Average nan V
# Times 3810.80-3810.78s: Average nan V
# Times 3810.80-3810.78s: Average nan V
# Times 400.67-3810.78s: Average nan V
# Times 400.67-3810.79s: Average nan V
# Times 400.67-3810.79s: Average nan V
# Times 400.67-3810.79s: Average nan V
# Times 400.67-3810.79s: Average nan V
# Times 400.67-3810.79s: Average nan V
# Times 400.67-400.92s: Average 1.016 V
# Times 2401.46-400.92s: Average nan V
# Times 2401.46-400.92s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-400.93s: Average nan V
# Times 2401.46-2401.45s: Average nan V
# Times 2401.47-2401.45s: Average nan V
# Times 2401.47-2401.45s: Average nan V
# Times 2401.47-2401.45s: Average nan V
# Times 2401.47-2401.46s: Average nan V
# Times 2401.47-2401.46s: Average nan V
# Times 400.93-2401.46s: Average nan V
# Times 400.93-2401.46s: Average nan V
# Times 400.94-2401.46s: Average nan V
# Times 400.94-2401.46s: Average nan V
# Times 400.94-2401.46s: Average nan V
# Times 400.94-2401.46s: Average nan V
# Times 400.94-405.85s: Average 1.016 V
# Times 2049.14-2049.14s: Average 2.940 V
# Times 405.87-2049.14s: Average nan V
# Times 405.87-2049.14s: Average nan V
# Times 405.87-2049.14s: Average nan V
# Times 405.87-2049.15s: Average nan V
# Times 405.87-407.12s: Average 1.016 V
# Times 1881.36-1881.36s: Average nan V
# Times 407.13-1881.36s: Average nan V
# Times 407.13-1881.36s: Average nan V
# Times 407.13-1881.36s: Average nan V
# Times 407.13-1881.37s: Average nan V
# Times 407.13-1881.37s: Average nan V
# Times 407.13-408.92s: Average 1.016 V
# Times 3659.79-408.92s: Average nan V
# Times 3659.80-408.92s: Average nan V
# Times 3659.80-408.92s: Average nan V
# Times 3659.80-408.92s: Average nan V
# Times 3659.80-3659.79s: Average nan V
# Times 3659.80-3659.80s: Average nan V
# Times 408.93-409.27s: Average 1.016 V
# Times 505.69-409.27s: Average nan V
# Times 505.70-409.27s: Average nan V
# Times 505.70-409.28s: Average nan V
# Times 505.70-409.28s: Average nan V
# Times 505.70-505.70s: Average nan V
# Times 409.29-409.60s: Average 1.016 V
# Times 2183.45-409.61s: Average nan V
# Times 2183.45-409.61s: Average nan V
# Times 2183.45-409.61s: Average nan V
# Times 2183.46-409.61s: Average nan V
# Times 2183.46-409.61s: Average nan V
# Times 2183.46-2183.45s: Average nan V
# Times 2183.46-2183.45s: Average nan V
# Times 2183.46-2183.45s: Average nan V
# Times 2183.46-2183.46s: Average nan V
# Times 409.62-410.16s: Average 1.016 V
# Times 589.56-410.16s: Average nan V
# Times 589.56-410.16s: Average nan V
# Times 589.56-410.16s: Average nan V
# Times 589.56-410.16s: Average nan V
# Times 589.56-410.16s: Average nan V
# Times 589.57-410.17s: Average nan V
# Times 589.57-589.55s: Average nan V
# Times 589.57-589.55s: Average nan V
# Times 589.57-589.55s: Average nan V
# Times 589.57-589.56s: Average nan V
# Times 589.57-589.56s: Average nan V
# Times 410.17-589.56s: Average nan V
# Times 410.17-589.56s: Average nan V
# Times 410.18-589.56s: Average nan V
# Times 410.18-410.69s: Average 1.016 V
# Times 3810.79-410.69s: Average nan V
# Times 3810.79-410.69s: Average nan V
# Times 3810.79-410.69s: Average nan V
# Times 3810.79-410.70s: Average nan V
# Times 3810.79-410.70s: Average nan V
# Times 3810.79-3810.78s: Average nan V
# Times 3810.80-3810.78s: Average nan V
# Times 3810.80-3810.78s: Average nan V
# Times 3810.80-3810.79s: Average nan V
# Times 410.71-410.96s: Average 1.016 V
# Times 2401.46-410.96s: Average nan V
# Times 2401.46-410.96s: Average nan V
# Times 2401.46-410.96s: Average nan V
# Times 2401.46-410.96s: Average nan V
# Times 2401.46-410.96s: Average nan V
# Times 2401.46-410.96s: Average nan V
# Times 2401.46-410.97s: Average nan V
# Times 2401.47-2401.45s: Average nan V
# Times 2401.47-2401.45s: Average nan V
# Times 2401.47-2401.46s: Average nan V
# Times 410.97-2401.46s: Average nan V
# Times 410.97-2401.46s: Average nan V
# Times 410.98-542.56s: Average 1.015 V
# Times 2921.53-542.56s: Average nan V
# Times 2921.53-542.56s: Average nan V
# Times 2921.53-542.56s: Average nan V
# Times 2921.53-542.56s: Average nan V
# Times 2921.53-542.57s: Average nan V
# Times 2921.54-542.57s: Average nan V
# Times 2921.54-542.57s: Average nan V
# Times 2921.54-542.57s: Average nan V
# Times 2921.54-2921.53s: Average nan V
# Times 2921.54-2921.53s: Average nan V
# Times 2921.54-2921.53s: Average nan V
# Times 2921.54-2921.53s: Average nan V
# Times 542.57-2921.53s: Average nan V
# Times 542.57-2921.53s: Average nan V
# Times 542.57-2921.53s: Average nan V
# Times 542.57-2921.53s: Average nan V
# Times 542.57-2921.53s: Average nan V
# Times 542.57-2921.53s: Average nan V
# Times 542.58-543.18s: Average 1.016 V
# Times 3307.47-543.18s: Average nan V
# Times 3307.47-543.18s: Average nan V
# Times 3307.47-543.18s: Average nan V
# Times 3307.47-543.18s: Average nan V
# Times 3307.47-543.19s: Average nan V
# Times 3307.47-543.19s: Average nan V
# Times 3307.47-543.19s: Average nan V
# Times 3307.47-543.19s: Average nan V
# Times 3307.47-543.19s: Average nan V
# Times 3307.48-3307.46s: Average nan V
# Times 3307.48-3307.46s: Average nan V
# Times 3307.48-3307.46s: Average nan V
# Times 3307.48-3307.47s: Average nan V
# Times 3307.48-3307.47s: Average nan V
# Times 543.19-3307.47s: Average nan V
# Times 543.19-3307.47s: Average nan V
# Times 543.19-3307.47s: Average nan V
# Times 543.19-3307.47s: Average nan V
# Times 543.19-3307.47s: Average nan V
# Times 543.20-3307.47s: Average nan V
# Times 543.20-545.58s: Average 1.016 V
# Times 203.71-545.59s: Average nan V
# Times 203.72-545.59s: Average nan V
# Times 203.72-545.59s: Average nan V
# Times 203.72-203.71s: Average nan V
# Times 203.72-203.71s: Average nan V
# Times 203.72-203.71s: Average nan V
# Times 203.72-203.71s: Average nan V
# Times 203.72-203.71s: Average nan V
# Times 203.72-203.71s: Average nan V
# Times 203.73-203.71s: Average nan V
# Times 545.59-203.71s: Average nan V
# Times 545.59-203.71s: Average nan V
# Times 545.59-203.72s: Average nan V
# Times 545.59-203.72s: Average nan V
# Times 545.60-203.72s: Average nan V
# Times 545.60-546.13s: Average 1.016 V
# Times 3592.70-546.14s: Average nan V
# Times 3592.70-546.14s: Average nan V
# Times 3592.70-546.14s: Average nan V
# Times 3592.70-3592.69s: Average nan V
# Times 3592.70-3592.69s: Average nan V
# Times 3592.70-3592.69s: Average nan V
# Times 3592.71-3592.69s: Average nan V
# Times 3592.71-3592.69s: Average nan V
# Times 3592.71-3592.69s: Average nan V
# Times 3592.71-3592.70s: Average nan V
# Times 546.15-3592.70s: Average nan V
# Times 546.15-3592.70s: Average nan V
# Times 546.15-3592.70s: Average nan V
# Times 546.15-3592.70s: Average nan V
# Times 546.15-3592.70s: Average nan V
# Times 546.15-3592.70s: Average nan V
# Times 546.15-547.62s: Average 1.016 V
# Times 1596.22-547.62s: Average nan V
# Times 1596.22-547.63s: Average nan V
# Times 1596.22-547.63s: Average nan V
# Times 1596.22-547.63s: Average nan V
# Times 1596.22-547.63s: Average nan V
# Times 1596.22-547.63s: Average nan V
# Times 1596.23-1596.21s: Average nan V
# Times 1596.23-1596.21s: Average nan V
# Times 1596.23-1596.21s: Average nan V
# Times 1596.23-1596.22s: Average nan V
# Times 1596.23-1596.22s: Average nan V
# Times 547.63-1596.22s: Average nan V
# Times 547.63-1596.22s: Average nan V
# Times 547.63-1596.22s: Average nan V
# Times 547.63-1596.22s: Average nan V
# Times 547.64-1596.22s: Average nan V
# Times 547.64-1596.22s: Average nan V
# Times 547.64-1596.22s: Average nan V
# Times 547.64-1596.22s: Average nan V
# Times 547.64-547.84s: Average 1.016 V
# Times 2.33-547.85s: Average nan V
# Times 2.34-2.33s: Average nan V
# Times 2.34-2.33s: Average nan V
# Times 2.34-2.33s: Average nan V
# Times 2.34-2.33s: Average nan V
# Times 2.35-2.33s: Average nan V
# Times 2.35-2.33s: Average nan V
# Times 547.85-2.33s: Average nan V
# Times 547.85-2.34s: Average nan V
# Times 547.86-2.34s: Average nan V
# Times 547.86-2.34s: Average nan V
# Times 547.86-2.34s: Average nan V
# Times 547.86-548.66s: Average 1.016 V
# Times 2669.91-548.67s: Average nan V
# Times 2669.92-548.67s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 548.68-2669.91s: Average nan V
# Times 548.68-2669.91s: Average nan V
# Times 548.68-2669.91s: Average nan V
# Times 548.68-2669.92s: Average nan V
# Times 548.68-2669.92s: Average nan V
# Times 548.68-551.24s: Average 1.016 V
# Times 3122.89-551.25s: Average nan V
# Times 3122.90-551.25s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 551.25-3122.89s: Average nan V
# Times 551.25-3122.89s: Average nan V
# Times 551.25-3122.89s: Average nan V
# Times 551.25-3122.90s: Average nan V
# Times 551.26-3122.90s: Average nan V
# Times 551.26-551.68s: Average 1.016 V
# Times 2502.13-551.69s: Average nan V
# Times 2502.13-551.69s: Average nan V
# Times 2502.14-551.69s: Average nan V
# Times 2502.14-2502.12s: Average nan V
# Times 2502.14-2502.12s: Average nan V
# Times 2502.14-2502.12s: Average nan V
# Times 2502.14-2502.12s: Average nan V
# Times 2502.14-2502.13s: Average nan V
# Times 2502.14-2502.13s: Average nan V
# Times 2502.14-2502.13s: Average nan V
# Times 551.70-2502.13s: Average nan V
# Times 551.70-2502.13s: Average nan V
# Times 551.70-2502.13s: Average nan V
# Times 551.70-2502.13s: Average nan V
# Times 551.70-2502.13s: Average nan V
# Times 551.70-552.59s: Average 1.016 V
# Times 2921.53-552.60s: Average nan V
# Times 2921.53-552.60s: Average nan V
# Times 2921.53-552.60s: Average nan V
# Times 2921.53-552.60s: Average nan V
# Times 2921.53-2921.53s: Average 0.160 V
# Times 552.61-553.22s: Average 1.016 V
# Times 3307.47-553.22s: Average nan V
# Times 3307.47-553.22s: Average nan V
# Times 3307.47-553.22s: Average nan V
# Times 3307.47-553.22s: Average nan V
# Times 3307.47-3307.47s: Average 0.180 V
# Times 553.23-553.62s: Average 1.016 V
# Times 2166.59-553.62s: Average nan V
# Times 2166.60-553.62s: Average nan V
# Times 2166.60-2166.59s: Average nan V
# Times 2166.60-2166.59s: Average nan V
# Times 2166.60-2166.59s: Average nan V
# Times 2166.60-2166.59s: Average nan V
# Times 2166.61-2166.59s: Average nan V
# Times 2166.61-2166.59s: Average nan V
# Times 2166.61-2166.59s: Average nan V
# Times 553.63-2166.60s: Average nan V
# Times 553.63-2166.60s: Average nan V
# Times 553.63-2166.60s: Average nan V
# Times 553.63-2166.60s: Average nan V
# Times 553.63-2166.60s: Average nan V
# Times 553.63-554.13s: Average 1.016 V
# Times 3022.24-554.13s: Average nan V
# Times 3022.25-3022.23s: Average nan V
# Times 3022.25-3022.23s: Average nan V
# Times 3022.25-3022.24s: Average nan V
# Times 3022.25-3022.24s: Average nan V
# Times 3022.25-3022.24s: Average nan V
# Times 3022.25-3022.24s: Average nan V
# Times 3022.25-3022.24s: Average nan V
# Times 554.14-3022.24s: Average nan V
# Times 554.14-3022.24s: Average nan V
# Times 554.14-3022.24s: Average nan V
# Times 554.14-3022.24s: Average nan V
# Times 554.14-3022.25s: Average nan V
# Times 554.14-554.37s: Average 1.016 V
# Times 3173.22-554.38s: Average nan V
# Times 3173.23-554.38s: Average nan V
# Times 3173.23-554.38s: Average nan V
# Times 3173.23-3173.22s: Average nan V
# Times 3173.23-3173.22s: Average nan V
# Times 3173.23-3173.22s: Average nan V
# Times 3173.23-3173.22s: Average nan V
# Times 3173.24-3173.22s: Average nan V
# Times 3173.24-3173.22s: Average nan V
# Times 554.38-3173.22s: Average nan V
# Times 554.38-3173.23s: Average nan V
# Times 554.38-3173.23s: Average nan V
# Times 554.39-3173.23s: Average nan V
# Times 554.39-3173.23s: Average nan V
# Times 554.39-555.61s: Average 1.016 V
# Times 203.71-555.62s: Average nan V
# Times 203.72-555.62s: Average nan V
# Times 203.72-555.62s: Average nan V
# Times 203.72-203.71s: Average nan V
# Times 203.72-203.72s: Average nan V
# Times 555.63-556.17s: Average 1.016 V
# Times 3592.70-556.17s: Average nan V
# Times 3592.70-556.17s: Average nan V
# Times 3592.70-556.18s: Average nan V
# Times 3592.70-556.18s: Average nan V
# Times 3592.70-3592.70s: Average nan V
# Times 556.19-557.12s: Average 1.016 V
# Times 3441.66-557.13s: Average nan V
# Times 3441.67-557.13s: Average nan V
# Times 3441.67-3441.65s: Average nan V
# Times 3441.67-3441.65s: Average nan V
# Times 3441.67-3441.66s: Average nan V
# Times 3441.67-3441.66s: Average nan V
# Times 3441.67-3441.66s: Average nan V
# Times 3441.67-3441.66s: Average nan V
# Times 557.13-3441.66s: Average nan V
# Times 557.14-3441.66s: Average nan V
# Times 557.14-3441.66s: Average nan V
# Times 557.14-3441.66s: Average nan V
# Times 557.14-3441.66s: Average nan V
# Times 557.14-557.19s: Average 1.016 V
# Times 3542.34-557.20s: Average nan V
# Times 3542.34-557.20s: Average nan V
# Times 3542.34-3542.33s: Average nan V
# Times 3542.34-3542.33s: Average nan V
# Times 3542.35-3542.33s: Average nan V
# Times 3542.35-3542.33s: Average nan V
# Times 3542.35-3542.33s: Average nan V
# Times 3542.35-3542.33s: Average nan V
# Times 557.20-3542.34s: Average nan V
# Times 557.20-3542.34s: Average nan V
# Times 557.20-3542.34s: Average nan V
# Times 557.20-3542.34s: Average nan V
# Times 557.21-3542.34s: Average nan V
# Times 557.21-557.26s: Average 1.016 V
# Times 3794.00-557.26s: Average nan V
# Times 3794.00-557.26s: Average nan V
# Times 3794.00-3793.99s: Average nan V
# Times 3794.00-3793.99s: Average nan V
# Times 3794.01-3793.99s: Average nan V
# Times 3794.01-3793.99s: Average nan V
# Times 3794.01-3793.99s: Average nan V
# Times 3794.01-3793.99s: Average nan V
# Times 3794.01-3793.99s: Average nan V
# Times 557.27-3794.00s: Average nan V
# Times 557.27-3794.00s: Average nan V
# Times 557.27-3794.00s: Average nan V
# Times 557.27-3794.00s: Average nan V
# Times 557.27-3794.00s: Average nan V
# Times 557.27-557.61s: Average 1.016 V
# Times 2854.46-557.62s: Average nan V
# Times 2854.47-2854.46s: Average nan V
# Times 2854.47-2854.46s: Average nan V
# Times 2854.47-2854.46s: Average nan V
# Times 2854.47-2854.46s: Average nan V
# Times 2854.48-2854.46s: Average nan V
# Times 2854.48-2854.46s: Average nan V
# Times 2854.48-2854.46s: Average nan V
# Times 557.62-2854.46s: Average nan V
# Times 557.62-2854.47s: Average nan V
# Times 557.63-2854.47s: Average nan V
# Times 557.63-2854.47s: Average nan V
# Times 557.63-2854.47s: Average nan V
# Times 557.63-557.66s: Average 1.016 V
# Times 1596.22-557.66s: Average nan V
# Times 1596.22-557.66s: Average nan V
# Times 1596.22-557.66s: Average nan V
# Times 1596.22-557.66s: Average nan V
# Times 1596.22-1596.22s: Average nan V
# Times 557.67-557.88s: Average 1.016 V
# Times 2.33-557.89s: Average nan V
# Times 2.34-2.33s: Average nan V
# Times 2.34-2.33s: Average nan V
# Times 2.34-2.33s: Average nan V
# Times 2.34-2.34s: Average nan V
# Times 557.89-558.70s: Average 1.016 V
# Times 2669.91-558.71s: Average nan V
# Times 2669.92-558.71s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.92s: Average nan V
# Times 558.72-559.03s: Average 1.016 V
# Times 3089.34-559.04s: Average nan V
# Times 3089.35-559.04s: Average nan V
# Times 3089.35-559.04s: Average nan V
# Times 3089.35-3089.33s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 559.04-3089.34s: Average nan V
# Times 559.04-3089.34s: Average nan V
# Times 559.05-3089.34s: Average nan V
# Times 559.05-3089.34s: Average nan V
# Times 559.05-3089.34s: Average nan V
# Times 559.05-3089.35s: Average nan V
# Times 559.05-561.27s: Average 1.016 V
# Times 3122.89-561.28s: Average nan V
# Times 3122.90-561.28s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.89s: Average nan V
# Times 3122.90-3122.90s: Average nan V
# Times 561.29-561.39s: Average 1.016 V
# Times 3374.62-561.39s: Average nan V
# Times 3374.62-561.39s: Average nan V
# Times 3374.63-561.39s: Average nan V
# Times 3374.63-561.39s: Average nan V
# Times 3374.63-561.39s: Average nan V
# Times 3374.63-561.39s: Average nan V
# Times 3374.63-561.39s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 561.40-3374.62s: Average nan V
# Times 561.40-3374.62s: Average nan V
# Times 561.40-3374.62s: Average nan V
# Times 561.40-3374.62s: Average nan V
# Times 561.40-3374.63s: Average nan V
# Times 561.40-3374.63s: Average nan V
# Times 561.40-561.72s: Average 1.016 V
# Times 2502.13-561.72s: Average nan V
# Times 2502.13-561.73s: Average nan V
# Times 2502.14-561.73s: Average nan V
# Times 2502.14-2502.12s: Average nan V
# Times 2502.14-2502.13s: Average nan V
# Times 561.74-562.69s: Average 1.016 V
# Times 2401.47-562.70s: Average nan V
# Times 2401.48-562.70s: Average nan V
# Times 2401.48-562.70s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.49-2401.47s: Average nan V
# Times 2401.49-2401.47s: Average nan V
# Times 562.71-2401.47s: Average nan V
# Times 562.71-2401.48s: Average nan V
# Times 562.71-2401.48s: Average nan V
# Times 562.71-2401.48s: Average nan V
# Times 562.71-2401.48s: Average nan V
# Times 562.71-562.92s: Average 1.016 V
# Times 3609.44-562.92s: Average nan V
# Times 3609.45-562.92s: Average nan V
# Times 3609.45-3609.43s: Average nan V
# Times 3609.45-3609.43s: Average nan V
# Times 3609.45-3609.43s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 562.93-3609.44s: Average nan V
# Times 562.93-3609.44s: Average nan V
# Times 562.93-3609.44s: Average nan V
# Times 562.93-3609.44s: Average nan V
# Times 562.93-3609.44s: Average nan V
# Times 562.93-563.65s: Average 1.016 V
# Times 2166.59-563.66s: Average nan V
# Times 2166.60-563.66s: Average nan V
# Times 2166.60-2166.59s: Average nan V
# Times 2166.60-2166.59s: Average nan V
# Times 2166.60-2166.60s: Average nan V
# Times 563.67-564.16s: Average 1.016 V
# Times 3022.24-564.17s: Average nan V
# Times 3022.25-3022.23s: Average nan V
# Times 3022.25-3022.23s: Average nan V
# Times 3022.25-3022.24s: Average nan V
# Times 3022.25-3022.25s: Average nan V
# Times 564.18-564.32s: Average 1.016 V
# Times 3072.57-564.32s: Average nan V
# Times 3072.57-564.32s: Average nan V
# Times 3072.57-564.32s: Average nan V
# Times 3072.57-3072.56s: Average nan V
# Times 3072.58-3072.56s: Average nan V
# Times 3072.58-3072.56s: Average nan V
# Times 3072.58-3072.56s: Average nan V
# Times 3072.58-3072.56s: Average nan V
# Times 3072.58-3072.57s: Average nan V
# Times 564.33-3072.57s: Average nan V
# Times 564.33-3072.57s: Average nan V
# Times 564.33-3072.57s: Average nan V
# Times 564.33-3072.57s: Average nan V
# Times 564.33-3072.57s: Average nan V
# Times 564.33-3072.57s: Average nan V
# Times 564.33-564.40s: Average 1.016 V
# Times 3173.22-564.41s: Average nan V
# Times 3173.23-564.41s: Average nan V
# Times 3173.23-564.41s: Average nan V
# Times 3173.23-3173.22s: Average nan V
# Times 3173.23-3173.23s: Average nan V
# Times 564.42-564.83s: Average 1.016 V
# Times 2015.59-564.83s: Average nan V
# Times 2015.59-564.83s: Average nan V
# Times 2015.59-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.59s: Average nan V
# Times 564.84-2015.59s: Average nan V
# Times 564.84-2015.59s: Average nan V
# Times 564.84-2015.59s: Average nan V
# Times 564.84-2015.59s: Average nan V
# Times 564.84-2015.59s: Average nan V
# Times 564.84-565.11s: Average 1.016 V
# Times 2921.57-565.12s: Average nan V
# Times 2921.57-565.12s: Average nan V
# Times 2921.57-565.12s: Average nan V
# Times 2921.58-2921.56s: Average nan V
# Times 2921.58-2921.56s: Average nan V
# Times 2921.58-2921.56s: Average nan V
# Times 2921.58-2921.56s: Average nan V
# Times 2921.58-2921.56s: Average nan V
# Times 2921.58-2921.57s: Average nan V
# Times 2921.58-2921.57s: Average nan V
# Times 565.13-2921.57s: Average nan V
# Times 565.13-2921.57s: Average nan V
# Times 565.13-2921.57s: Average nan V
# Times 565.13-2921.57s: Average nan V
# Times 565.13-2921.57s: Average nan V
# Times 565.13-565.27s: Average 1.016 V
# Times 2988.68-565.28s: Average nan V
# Times 2988.68-565.28s: Average nan V
# Times 2988.68-2988.67s: Average nan V
# Times 2988.68-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 565.28-2988.68s: Average nan V
# Times 565.28-2988.68s: Average nan V
# Times 565.28-2988.68s: Average nan V
# Times 565.29-2988.68s: Average nan V
# Times 565.29-2988.68s: Average nan V
# Times 565.29-566.14s: Average 1.016 V
# Times 3022.23-566.14s: Average nan V
# Times 3022.24-566.14s: Average nan V
# Times 3022.24-3022.22s: Average nan V
# Times 3022.24-3022.22s: Average nan V
# Times 3022.24-3022.23s: Average nan V
# Times 3022.24-3022.23s: Average nan V
# Times 3022.24-3022.23s: Average nan V
# Times 3022.24-3022.23s: Average nan V
# Times 566.15-3022.23s: Average nan V
# Times 566.15-3022.23s: Average nan V
# Times 566.15-3022.23s: Average nan V
# Times 566.15-3022.23s: Average nan V
# Times 566.15-566.47s: Average 1.016 V
# Times 3710.11-566.48s: Average nan V
# Times 3710.11-566.48s: Average nan V
# Times 3710.11-566.48s: Average nan V
# Times 3710.11-3710.10s: Average nan V
# Times 3710.11-3710.10s: Average nan V
# Times 3710.12-3710.10s: Average nan V
# Times 3710.12-3710.10s: Average nan V
# Times 3710.12-3710.10s: Average nan V
# Times 3710.12-3710.11s: Average nan V
# Times 566.48-3710.11s: Average nan V
# Times 566.48-3710.11s: Average nan V
# Times 566.48-3710.11s: Average nan V
# Times 566.48-3710.11s: Average nan V
# Times 566.49-3710.11s: Average nan V
# Times 566.49-567.16s: Average 1.016 V
# Times 3441.66-567.16s: Average nan V
# Times 3441.67-567.16s: Average nan V
# Times 3441.67-3441.65s: Average nan V
# Times 3441.67-3441.65s: Average nan V
# Times 3441.67-3441.66s: Average nan V
# Times 567.17-567.20s: Average 1.016 V
# Times 3290.67-567.21s: Average nan V
# Times 3290.67-567.21s: Average nan V
# Times 3290.67-567.21s: Average nan V
# Times 3290.67-3290.66s: Average nan V
# Times 3290.67-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 3290.68-3290.67s: Average nan V
# Times 567.21-3290.67s: Average nan V
# Times 567.22-3290.67s: Average nan V
# Times 567.22-3290.67s: Average nan V
# Times 567.22-3290.67s: Average nan V
# Times 567.22-3290.67s: Average nan V
# Times 567.22-567.22s: Average 1.016 V
# Times 3542.34-567.23s: Average nan V
# Times 3542.34-567.23s: Average nan V
# Times 3542.34-3542.33s: Average nan V
# Times 3542.34-3542.33s: Average nan V
# Times 3542.34-3542.34s: Average nan V
# Times 567.24-567.29s: Average 1.016 V
# Times 3794.00-567.30s: Average nan V
# Times 3794.00-3793.99s: Average nan V
# Times 3794.00-3793.99s: Average nan V
# Times 3794.01-3794.00s: Average nan V
# Times 567.31-567.65s: Average 1.016 V
# Times 2854.46-567.65s: Average nan V
# Times 2854.47-2854.46s: Average nan V
# Times 2854.47-2854.46s: Average nan V
# Times 2854.47-2854.46s: Average nan V
# Times 2854.47-2854.47s: Average nan V
# Times 567.66-569.07s: Average 1.016 V
# Times 3089.34-569.07s: Average nan V
# Times 3089.35-569.07s: Average nan V
# Times 3089.35-569.07s: Average nan V
# Times 3089.35-569.07s: Average nan V
# Times 3089.35-3089.33s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 3089.35-3089.34s: Average nan V
# Times 569.08-3089.34s: Average nan V
# Times 569.08-3089.34s: Average nan V
# Times 569.08-3089.34s: Average nan V
# Times 569.08-3089.34s: Average nan V
# Times 569.08-3089.34s: Average nan V
# Times 569.08-3089.35s: Average nan V
# Times 569.08-569.27s: Average 1.016 V
# Times 2619.62-569.27s: Average nan V
# Times 2619.62-569.27s: Average nan V
# Times 2619.62-2619.61s: Average nan V
# Times 2619.62-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 569.28-2619.62s: Average nan V
# Times 569.28-2619.62s: Average nan V
# Times 569.28-2619.62s: Average nan V
# Times 569.28-2619.62s: Average nan V
# Times 569.28-2619.62s: Average nan V
# Times 569.28-569.62s: Average 1.016 V
# Times 254.03-254.03s: Average nan V
# Times 254.04-254.03s: Average nan V
# Times 254.05-254.03s: Average nan V
# Times 254.05-254.03s: Average nan V
# Times 254.05-254.03s: Average nan V
# Times 569.63-254.03s: Average nan V
# Times 569.63-254.03s: Average nan V
# Times 569.63-254.04s: Average nan V
# Times 569.63-254.04s: Average nan V
# Times 569.63-254.04s: Average nan V
# Times 569.64-254.04s: Average nan V
# Times 569.64-571.42s: Average 1.016 V
# Times 1210.30-1210.30s: Average nan V
# Times 1210.32-1210.30s: Average nan V
# Times 1210.32-1210.30s: Average nan V
# Times 1210.32-1210.30s: Average nan V
# Times 3374.62-1210.30s: Average nan V
# Times 3374.62-1210.31s: Average nan V
# Times 3374.62-1210.31s: Average nan V
# Times 3374.62-1210.31s: Average nan V
# Times 3374.62-1210.31s: Average nan V
# Times 3374.62-1210.31s: Average nan V
# Times 3374.62-1210.31s: Average nan V
# Times 3374.62-1210.31s: Average nan V
# Times 3374.63-1210.31s: Average nan V
# Times 3374.63-1210.32s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 3374.63-3374.62s: Average nan V
# Times 571.43-3374.62s: Average nan V
# Times 571.43-3374.62s: Average nan V
# Times 571.43-3374.62s: Average nan V
# Times 571.43-3374.62s: Average nan V
# Times 571.43-3374.63s: Average nan V
# Times 571.44-3374.63s: Average nan V
# Times 571.44-571.64s: Average 1.016 V
# Times 3743.66-3743.65s: Average nan V
# Times 571.65-3743.66s: Average nan V
# Times 571.65-3743.66s: Average nan V
# Times 571.65-3743.66s: Average nan V
# Times 571.66-3743.66s: Average nan V
# Times 571.66-3743.66s: Average nan V
# Times 571.66-3743.66s: Average nan V
# Times 571.66-3743.66s: Average nan V
# Times 571.66-572.20s: Average 1.016 V
# Times 3676.55-3676.55s: Average 2.912 V
# Times 572.21-3676.55s: Average nan V
# Times 572.21-3676.55s: Average nan V
# Times 572.21-3676.55s: Average nan V
# Times 572.21-3676.55s: Average nan V
# Times 572.21-572.73s: Average 1.016 V
# Times 2401.47-572.74s: Average nan V
# Times 2401.48-572.74s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.48-2401.47s: Average nan V
# Times 2401.49-2401.47s: Average nan V
# Times 2401.49-2401.47s: Average nan V
# Times 572.74-2401.47s: Average nan V
# Times 572.74-2401.47s: Average nan V
# Times 572.74-2401.48s: Average nan V
# Times 572.74-2401.48s: Average nan V
# Times 572.74-2401.48s: Average nan V
# Times 572.75-2401.48s: Average nan V
# Times 572.75-572.95s: Average 1.016 V
# Times 3609.44-572.96s: Average nan V
# Times 3609.45-572.96s: Average nan V
# Times 3609.45-572.96s: Average nan V
# Times 3609.45-572.96s: Average nan V
# Times 3609.45-3609.43s: Average nan V
# Times 3609.45-3609.43s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 3609.45-3609.44s: Average nan V
# Times 572.96-3609.44s: Average nan V
# Times 572.97-3609.44s: Average nan V
# Times 572.97-3609.44s: Average nan V
# Times 572.97-3609.44s: Average nan V
# Times 572.97-3609.44s: Average nan V
# Times 572.97-573.08s: Average 1.016 V
# Times 2468.57-2468.57s: Average 2.962 V
# Times 573.10-2468.57s: Average nan V
# Times 573.10-2468.57s: Average nan V
# Times 573.10-2468.57s: Average nan V
# Times 573.10-574.35s: Average 1.016 V
# Times 3072.57-574.36s: Average nan V
# Times 3072.57-574.36s: Average nan V
# Times 3072.57-574.36s: Average nan V
# Times 3072.57-574.36s: Average nan V
# Times 3072.57-3072.56s: Average nan V
# Times 3072.58-3072.56s: Average nan V
# Times 3072.58-3072.56s: Average nan V
# Times 3072.58-3072.57s: Average nan V
# Times 574.36-3072.57s: Average nan V
# Times 574.36-3072.57s: Average nan V
# Times 574.36-3072.57s: Average nan V
# Times 574.36-3072.57s: Average nan V
# Times 574.36-3072.57s: Average nan V
# Times 574.37-3072.57s: Average nan V
# Times 574.37-574.68s: Average 1.016 V
# Times 3441.71-3441.71s: Average 3.011 V
# Times 574.70-3441.71s: Average nan V
# Times 574.70-3441.71s: Average nan V
# Times 574.70-3441.71s: Average nan V
# Times 574.70-3441.71s: Average nan V
# Times 574.70-574.86s: Average 1.016 V
# Times 2015.59-574.87s: Average nan V
# Times 2015.59-574.87s: Average nan V
# Times 2015.59-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.58s: Average nan V
# Times 2015.60-2015.59s: Average nan V
# Times 574.87-2015.59s: Average nan V
# Times 574.87-2015.59s: Average nan V
# Times 574.87-2015.59s: Average nan V
# Times 574.87-2015.59s: Average nan V
# Times 574.88-2015.59s: Average nan V
# Times 574.88-2015.59s: Average nan V
# Times 574.88-575.15s: Average 1.016 V
# Times 2921.57-575.15s: Average nan V
# Times 2921.57-575.16s: Average nan V
# Times 2921.57-575.16s: Average nan V
# Times 2921.58-575.16s: Average nan V
# Times 2921.58-2921.56s: Average nan V
# Times 2921.58-2921.57s: Average nan V
# Times 2921.58-2921.57s: Average nan V
# Times 575.16-2921.57s: Average nan V
# Times 575.16-2921.57s: Average nan V
# Times 575.16-2921.57s: Average nan V
# Times 575.16-2921.57s: Average nan V
# Times 575.16-2921.57s: Average nan V
# Times 575.17-575.30s: Average 1.016 V
# Times 2988.68-575.31s: Average nan V
# Times 2988.68-575.31s: Average nan V
# Times 2988.68-2988.67s: Average nan V
# Times 2988.68-2988.67s: Average nan V
# Times 2988.68-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 2988.69-2988.67s: Average nan V
# Times 575.32-2988.68s: Average nan V
# Times 575.32-2988.68s: Average nan V
# Times 575.32-2988.68s: Average nan V
# Times 575.32-2988.68s: Average nan V
# Times 575.32-2988.68s: Average nan V
# Times 575.32-2988.68s: Average nan V
# Times 575.32-576.17s: Average 1.016 V
# Times 3022.23-576.18s: Average nan V
# Times 3022.24-576.18s: Average nan V
# Times 3022.24-3022.22s: Average nan V
# Times 3022.24-3022.22s: Average nan V
# Times 3022.24-3022.23s: Average nan V
# Times 3022.24-3022.23s: Average nan V
# Times 3022.24-3022.23s: Average nan V
# Times 576.18-3022.23s: Average nan V
# Times 576.18-3022.23s: Average nan V
# Times 576.18-3022.23s: Average nan V
# Times 576.18-3022.23s: Average nan V
# Times 576.19-3022.23s: Average nan V
# Times 576.19-576.50s: Average 1.016 V
# Times 3710.11-576.51s: Average nan V
# Times 3710.11-576.51s: Average nan V
# Times 3710.11-576.51s: Average nan V
# Times 3710.11-3710.10s: Average nan V
# Times 3710.11-3710.10s: Average nan V
# Times 3710.11-3710.10s: Average nan V
# Times 3710.12-3710.11s: Average nan V
# Times 576.52-3710.11s: Average nan V
# Times 576.52-3710.11s: Average nan V
# Times 576.52-3710.11s: Average nan V
# Times 576.52-577.24s: Average 1.016 V
# Times 3290.67-577.24s: Average nan V
# Times 3290.67-577.24s: Average nan V
# Times 3290.67-577.24s: Average nan V
# Times 3290.67-3290.66s: Average nan V
# Times 3290.67-3290.66s: Average nan V
# Times 3290.67-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 3290.68-3290.66s: Average nan V
# Times 577.25-3290.67s: Average nan V
# Times 577.25-3290.67s: Average nan V
# Times 577.25-3290.67s: Average nan V
# Times 577.25-3290.67s: Average nan V
# Times 577.25-579.30s: Average 1.016 V
# Times 2619.62-579.31s: Average nan V
# Times 2619.62-579.31s: Average nan V
# Times 2619.62-2619.61s: Average nan V
# Times 2619.62-2619.61s: Average nan V
# Times 2619.62-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 2619.63-2619.61s: Average nan V
# Times 579.31-2619.61s: Average nan V
# Times 579.31-2619.62s: Average nan V
# Times 579.31-2619.62s: Average nan V
# Times 579.31-2619.62s: Average nan V
# Times 579.32-2619.62s: Average nan V
# Times 579.32-2619.62s: Average nan V
# Times 579.32-579.66s: Average 1.016 V
# Times 254.03-254.03s: Average nan V
# Times 254.04-254.03s: Average nan V
# Times 254.05-254.03s: Average nan V
# Times 254.05-254.03s: Average nan V
# Times 254.05-254.03s: Average nan V
# Times 254.05-254.03s: Average nan V
# Times 579.67-254.03s: Average nan V
# Times 579.67-254.03s: Average nan V
# Times 579.67-254.04s: Average nan V
# Times 579.67-254.04s: Average nan V
# Times 579.67-254.04s: Average nan V
# Times 579.67-254.04s: Average nan V
# Times 579.67-254.04s: Average nan V
# Times 579.67-254.04s: Average nan V
# Times 579.67-254.04s: Average nan V
# Times 579.67-581.45s: Average 1.016 V
# Times 1210.30-1210.30s: Average nan V
# Times 1210.32-1210.30s: Average nan V
# Times 1210.32-1210.30s: Average nan V
# Times 1210.32-1210.30s: Average nan V
# Times 581.46-1210.30s: Average nan V
# Times 581.47-1210.31s: Average nan V
# Times 581.47-1210.31s: Average nan V
# Times 581.47-1210.31s: Average nan V
# Times 581.47-1210.31s: Average nan V
# Times 581.47-1210.31s: Average nan V
# Times 581.47-1210.31s: Average nan V
# Times 581.47-1210.31s: Average nan V
# Times 581.47-581.68s: Average 1.016 V
# Times 3743.66-3743.65s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-3743.66s: Average nan V
# Times 581.69-582.23s: Average 1.016 V
# Times 3676.55-3676.55s: Average 2.912 V
# Times 582.24-3676.55s: Average nan V
# Times 582.24-3676.55s: Average nan V
# Times 582.25-3676.55s: Average nan V
# Times 582.25-3676.55s: Average nan V
# Times 582.25-3676.55s: Average nan V
# Times 582.25-3676.55s: Average nan V
# Times 582.25-583.12s: Average 1.016 V
# Times 2468.57-2468.57s: Average 2.962 V
# Times 583.13-2468.57s: Average nan V
# Times 583.13-2468.57s: Average nan V
# Times 583.13-2468.57s: Average nan V
# Times 583.14-2468.57s: Average nan V
# Times 583.14-584.72s: Average 1.016 V
# Times 3441.71-3441.71s: Average 3.011 V
# Times 584.73-3441.71s: Average nan V
# Times 584.73-3441.71s: Average nan V
# Times 584.73-3441.71s: Average nan V
# Times 584.73-3441.71s: Average nan V
# Times 584.73-590.96s: Average 1.016 V
# Times 723.80-723.80s: Average 2.983 V
# Times 590.97-723.81s: Average nan V
# Times 590.97-723.81s: Average nan V
# Times 590.97-723.81s: Average nan V
# Times 590.97-723.81s: Average nan V
# Times 590.97-723.81s: Average nan V
# Times 590.97-591.22s: Average 1.016 V
# Times 2032.47-2032.47s: Average nan V
# Times 591.23-2032.47s: Average nan V
# Times 591.23-2032.47s: Average nan V
# Times 591.23-2032.47s: Average nan V
# Times 591.23-2032.47s: Average nan V
# Times 591.24-2032.48s: Average nan V
# Times 591.24-2032.48s: Average nan V
# Times 591.24-2032.48s: Average nan V
# Times 591.24-2032.48s: Average nan V
# Times 591.24-591.36s: Average 1.016 V
# Times 1342.17-591.36s: Average nan V
# Times 1342.17-591.36s: Average nan V
# Times 1342.17-591.36s: Average nan V
# Times 1342.17-591.36s: Average nan V
# Times 1342.17-591.36s: Average nan V
# Times 1342.18-591.36s: Average nan V
# Times 1342.18-591.36s: Average nan V
# Times 1342.18-1342.16s: Average nan V
# Times 1342.18-1342.16s: Average nan V
# Times 1342.18-1342.16s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 591.37-1342.17s: Average nan V
# Times 591.37-1342.17s: Average nan V
# Times 591.37-1342.17s: Average nan V
# Times 591.37-1342.17s: Average nan V
# Times 591.37-1342.17s: Average nan V
# Times 591.37-1342.17s: Average nan V
# Times 591.37-1342.17s: Average nan V
# Times 591.37-592.18s: Average 1.016 V
# Times 1006.62-592.18s: Average nan V
# Times 1006.63-592.18s: Average nan V
# Times 1006.63-592.18s: Average nan V
# Times 1006.63-592.18s: Average nan V
# Times 1006.63-592.18s: Average nan V
# Times 1006.63-592.18s: Average nan V
# Times 1006.63-592.18s: Average nan V
# Times 1006.63-1006.62s: Average nan V
# Times 1006.63-1006.62s: Average nan V
# Times 1006.63-1006.62s: Average nan V
# Times 1006.63-1006.62s: Average nan V
# Times 1006.64-1006.62s: Average nan V
# Times 1006.64-1006.62s: Average nan V
# Times 592.19-1006.62s: Average nan V
# Times 592.19-1006.63s: Average nan V
# Times 592.19-1006.63s: Average nan V
# Times 592.19-1006.63s: Average nan V
# Times 592.19-1006.63s: Average nan V
# Times 592.19-1006.63s: Average nan V
# Times 592.19-1006.63s: Average nan V
# Times 592.19-593.58s: Average 1.016 V
# Times 1847.88-1847.88s: Average nan V
# Times 593.59-1847.88s: Average nan V
# Times 593.59-1847.88s: Average nan V
# Times 593.59-1847.88s: Average nan V
# Times 593.59-1847.88s: Average nan V
# Times 593.59-1847.89s: Average nan V
# Times 593.59-1847.89s: Average nan V
# Times 593.59-1847.89s: Average nan V
# Times 593.59-594.49s: Average 1.016 V
# Times 1260.68-1260.68s: Average 2.952 V
# Times 594.50-1260.68s: Average nan V
# Times 594.50-1260.68s: Average nan V
# Times 594.50-1260.68s: Average nan V
# Times 594.50-1260.68s: Average nan V
# Times 594.50-1260.68s: Average nan V
# Times 594.50-1260.68s: Average nan V
# Times 594.50-1260.68s: Average nan V
# Times 594.50-595.24s: Average 1.016 V
# Times 3760.44-3760.44s: Average 2.983 V
# Times 595.25-3760.44s: Average nan V
# Times 595.25-3760.44s: Average nan V
# Times 595.26-3760.44s: Average nan V
# Times 595.26-3760.45s: Average nan V
# Times 595.26-3760.45s: Average nan V
# Times 595.26-595.35s: Average 1.016 V
# Times 1795.15-595.35s: Average nan V
# Times 1795.15-595.35s: Average nan V
# Times 1795.15-595.35s: Average nan V
# Times 1795.15-595.36s: Average nan V
# Times 1795.15-595.36s: Average nan V
# Times 1795.15-595.36s: Average nan V
# Times 1795.16-595.36s: Average nan V
# Times 1795.16-595.36s: Average nan V
# Times 1795.16-1795.14s: Average nan V
# Times 1795.16-1795.14s: Average nan V
# Times 1795.16-1795.14s: Average nan V
# Times 1795.16-1795.14s: Average nan V
# Times 1795.16-1795.15s: Average nan V
# Times 1795.16-1795.15s: Average nan V
# Times 595.36-1795.15s: Average nan V
# Times 595.36-1795.15s: Average nan V
# Times 595.36-1795.15s: Average nan V
# Times 595.36-1795.15s: Average nan V
# Times 595.37-1795.15s: Average nan V
# Times 595.37-1795.15s: Average nan V
# Times 595.37-1795.15s: Average nan V
# Times 595.37-595.64s: Average 1.016 V
# Times 3106.19-3106.19s: Average nan V
# Times 595.65-3106.19s: Average nan V
# Times 595.65-3106.19s: Average nan V
# Times 595.65-3106.19s: Average nan V
# Times 595.65-3106.19s: Average nan V
# Times 595.65-3106.19s: Average nan V
# Times 595.65-3106.19s: Average nan V
# Times 595.65-3106.20s: Average nan V
# Times 595.66-3106.20s: Average nan V
# Times 595.66-3106.20s: Average nan V
# Times 595.66-597.10s: Average 1.016 V
# Times 3575.88-3575.88s: Average 2.973 V
# Times 597.12-3575.88s: Average nan V
# Times 597.12-3575.88s: Average nan V
# Times 597.12-3575.89s: Average nan V
# Times 597.12-3575.89s: Average nan V
# Times 597.12-598.57s: Average 1.016 V
# Times 2921.56-2921.56s: Average 2.961 V
# Times 598.58-2921.56s: Average nan V
# Times 598.59-2921.56s: Average nan V
# Times 598.59-2921.56s: Average nan V
# Times 598.59-2921.57s: Average nan V
# Times 598.59-600.99s: Average 1.016 V
# Times 723.80-723.80s: Average 2.983 V
# Times 601.00-723.81s: Average nan V
# Times 601.00-723.81s: Average nan V
# Times 601.00-723.81s: Average nan V
# Times 601.00-723.81s: Average nan V
# Times 601.01-601.26s: Average 1.016 V
# Times 2032.47-2032.47s: Average nan V
# Times 601.27-2032.47s: Average nan V
# Times 601.27-2032.47s: Average nan V
# Times 601.27-2032.47s: Average nan V
# Times 601.27-2032.48s: Average nan V
# Times 601.27-601.39s: Average 1.016 V
# Times 1342.17-601.39s: Average nan V
# Times 1342.17-601.39s: Average nan V
# Times 1342.17-601.39s: Average nan V
# Times 1342.17-601.39s: Average nan V
# Times 1342.17-601.40s: Average nan V
# Times 1342.18-601.40s: Average nan V
# Times 1342.18-601.40s: Average nan V
# Times 1342.18-601.40s: Average nan V
# Times 1342.18-1342.16s: Average nan V
# Times 1342.18-1342.16s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 1342.18-1342.17s: Average nan V
# Times 601.40-1342.17s: Average nan V
# Times 601.40-1342.17s: Average nan V
# Times 601.40-1342.17s: Average nan V
# Times 601.40-1342.17s: Average nan V
# Times 601.40-1342.17s: Average nan V
# Times 601.41-1342.17s: Average nan V
# Times 601.41-602.21s: Average 1.016 V
# Times 1006.62-602.21s: Average nan V
# Times 1006.63-602.21s: Average nan V
# Times 1006.63-602.21s: Average nan V
# Times 1006.63-602.22s: Average nan V
# Times 1006.63-602.22s: Average nan V
# Times 1006.63-602.22s: Average nan V
# Times 1006.63-602.22s: Average nan V
# Times 1006.63-602.22s: Average nan V
# Times 1006.63-1006.62s: Average nan V
# Times 1006.63-1006.62s: Average nan V
# Times 1006.63-1006.62s: Average nan V
# Times 1006.64-1006.62s: Average nan V
# Times 1006.64-1006.62s: Average nan V
# Times 1006.64-1006.62s: Average nan V
# Times 602.22-1006.62s: Average nan V
# Times 602.22-1006.62s: Average nan V
# Times 602.22-1006.63s: Average nan V
# Times 602.22-1006.63s: Average nan V
# Times 602.22-1006.63s: Average nan V
# Times 602.23-1006.63s: Average nan V
# Times 602.23-1006.63s: Average nan V
# Times 602.23-603.61s: Average 1.016 V
# Times 1847.88-1847.88s: Average nan V
# Times 603.62-1847.88s: Average nan V
# Times 603.62-1847.88s: Average nan V
# Times 603.62-1847.88s: Average nan V
# Times 603.62-1847.89s: Average nan V
# Times 603.63-604.52s: Average 1.016 V
# Times 1260.68-1260.68s: Average 2.952 V
# Times 604.53-1260.68s: Average nan V
# Times 604.53-1260.68s: Average nan V
# Times 604.53-1260.68s: Average nan V
# Times 604.53-1260.68s: Average nan V
# Times 604.54-605.27s: Average 1.016 V
# Times 3760.44-3760.44s: Average 2.983 V
# Times 605.29-3760.44s: Average nan V
# Times 605.29-3760.44s: Average nan V
# Times 605.29-3760.44s: Average nan V
# Times 605.29-3760.45s: Average nan V
# Times 605.29-605.39s: Average 1.016 V
# Times 1795.15-605.39s: Average nan V
# Times 1795.15-605.39s: Average nan V
# Times 1795.15-605.39s: Average nan V
# Times 1795.15-605.39s: Average nan V
# Times 1795.15-605.39s: Average nan V
# Times 1795.15-605.39s: Average nan V
# Times 1795.16-605.39s: Average nan V
# Times 1795.16-1795.15s: Average nan V
# Times 605.40-605.67s: Average 1.016 V
# Times 3106.19-3106.19s: Average nan V
# Times 605.68-3106.19s: Average nan V
# Times 605.69-3106.19s: Average nan V
# Times 605.69-3106.19s: Average nan V
# Times 605.69-3106.20s: Average nan V
# Times 605.69-606.25s: Average 1.016 V
# Times 3324.22-3324.22s: Average 2.961 V
# ...
# Times 739.44-2518.92s: Average nan V
# Times 739.44-2518.92s: Average nan V
# Times 739.45-740.18s: Average 1.017 V
# Times 1378.06-740.19s: Average nan V
# Times 1378.06-740.19s: Average nan V
# Times 1378.06-740.19s: Average nan V
# Times 1378.06-740.19s: Average nan V
# Times 1378.06-1378.06s: Average 0.316 V
# Times 740.20-740.21s: Average 1.017 V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.26-740.21s: Average nan V
# Times 2267.27-2267.25s: Average nan V
# Times 2267.27-2267.25s: Average nan V
# Times 2267.27-2267.25s: Average nan V
# Times 2267.27-2267.26s: Average nan V
# Times 2267.27-2267.26s: Average nan V
# Times 2267.27-2267.26s: Average nan V
# Times 740.22-2267.26s: Average nan V
# Times 740.22-2267.26s: Average nan V
# Times 740.22-2267.26s: Average nan V
# Times 740.22-2267.26s: Average nan V
# Times 740.22-2267.26s: Average nan V
# Times 740.22-740.92s: Average 1.017 V
# Times 1109.63-740.92s: Average nan V
# Times 1109.63-740.92s: Average nan V
# Times 1109.63-740.92s: Average nan V
# Times 1109.63-740.92s: Average nan V
# Times 1109.63-1109.63s: Average 0.277 V
# Times 740.93-741.60s: Average 1.017 V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-741.61s: Average nan V
# Times 2686.69-2686.68s: Average nan V
# Times 2686.70-2686.68s: Average nan V
# Times 2686.70-2686.68s: Average nan V
# Times 2686.70-2686.68s: Average nan V
# Times 2686.70-2686.69s: Average nan V
# Times 2686.70-2686.69s: Average nan V
# Times 741.62-2686.69s: Average nan V
# Times 741.62-2686.69s: Average nan V
# Times 741.62-2686.69s: Average nan V
# Times 741.62-2686.69s: Average nan V
# Times 741.62-2686.69s: Average nan V
# Times 741.62-2686.69s: Average nan V
# Times 741.62-742.74s: Average 1.017 V
# Times 3072.55-742.74s: Average nan V
# Times 3072.55-742.74s: Average nan V
# Times 3072.55-742.74s: Average nan V
# Times 3072.55-742.74s: Average nan V
# Times 3072.56-742.74s: Average nan V
# Times 3072.56-742.74s: Average nan V
# Times 3072.56-742.74s: Average nan V
# Times 3072.56-742.74s: Average nan V
# Times 3072.56-742.74s: Average nan V
# Times 3072.56-3072.55s: Average nan V
# Times 3072.56-3072.55s: Average nan V
# Times 3072.56-3072.55s: Average nan V
# Times 3072.56-3072.55s: Average nan V
# Times 3072.56-3072.55s: Average nan V
# Times 3072.56-3072.55s: Average nan V
# Times 3072.57-3072.55s: Average nan V
# Times 742.75-3072.55s: Average nan V
# Times 742.75-3072.55s: Average nan V
# Times 742.75-3072.55s: Average nan V
# Times 742.75-3072.56s: Average nan V
# Times 742.75-3072.56s: Average nan V
# Times 742.75-3072.56s: Average nan V
# Times 742.75-743.20s: Average 1.017 V
# Times 1914.92-743.20s: Average nan V
# Times 1914.92-743.20s: Average nan V
# Times 1914.92-743.21s: Average nan V
# Times 1914.92-1914.92s: Average 0.254 V
# Times 743.22-743.34s: Average 1.017 V
# Times 589.53-743.34s: Average nan V
# Times 589.53-743.34s: Average nan V
# Times 589.53-743.34s: Average nan V
# Times 589.53-743.34s: Average nan V
# Times 589.53-743.34s: Average nan V
# Times 589.53-743.34s: Average nan V
# Times 589.53-743.34s: Average nan V
# Times 589.53-743.34s: Average nan V
# Times 589.53-589.52s: Average nan V
# Times 589.54-589.52s: Average nan V
# Times 589.54-589.52s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 743.35-589.53s: Average nan V
# Times 743.35-589.53s: Average nan V
# Times 743.35-589.53s: Average nan V
# Times 743.35-589.53s: Average nan V
# Times 743.35-589.53s: Average nan V
# Times 743.35-589.53s: Average nan V
# Times 743.35-743.85s: Average 1.017 V
# Times 2468.58-743.85s: Average nan V
# Times 2468.58-743.85s: Average nan V
# Times 2468.59-743.85s: Average nan V
# Times 2468.59-743.85s: Average nan V
# Times 2468.59-2468.59s: Average 0.238 V
# Times 743.86-743.94s: Average 1.017 V
# Times 1243.84-743.94s: Average nan V
# Times 1243.84-743.94s: Average nan V
# Times 1243.84-743.94s: Average nan V
# Times 1243.84-1243.84s: Average 0.301 V
# Times 743.95-744.98s: Average 1.017 V
# Times 2938.35-744.98s: Average nan V
# Times 2938.36-744.98s: Average nan V
# Times 2938.36-744.98s: Average nan V
# Times 2938.36-744.98s: Average nan V
# Times 2938.36-2938.36s: Average 0.238 V
# Times 745.00-748.20s: Average 1.017 V
# Times 2487.83-748.20s: Average nan V
# Times 2487.83-748.20s: Average nan V
# Times 2487.83-748.20s: Average nan V
# Times 2487.83-748.20s: Average nan V
# Times 2487.83-748.20s: Average nan V
# Times 2487.83-748.20s: Average nan V
# Times 2487.83-748.20s: Average nan V
# Times 2487.83-748.21s: Average nan V
# Times 2487.84-2487.82s: Average nan V
# Times 2487.84-2487.82s: Average nan V
# Times 2487.84-2487.82s: Average nan V
# Times 2487.84-2487.82s: Average nan V
# Times 2487.84-2487.82s: Average nan V
# Times 2487.84-2487.82s: Average nan V
# Times 2487.84-2487.83s: Average nan V
# Times 2487.84-2487.83s: Average nan V
# Times 1797.47-2487.83s: Average nan V
# Times 1797.47-2487.83s: Average nan V
# Times 1797.47-2487.83s: Average nan V
# Times 1797.47-2487.83s: Average nan V
# Times 1797.47-2487.83s: Average nan V
# Times 1797.48-2487.83s: Average nan V
# Times 1797.48-2487.84s: Average nan V
# Times 1797.48-2487.84s: Average nan V
# Times 1797.48-2487.84s: Average nan V
# Times 1797.48-2487.84s: Average nan V
# Times 1797.48-1797.48s: Average 0.238 V
# Times 748.22-748.46s: Average 1.017 V
# Times 1680.04-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-748.47s: Average nan V
# Times 1680.05-1680.04s: Average nan V
# Times 1680.05-1680.04s: Average nan V
# Times 1680.06-1680.04s: Average nan V
# Times 1680.06-1680.04s: Average nan V
# Times 1680.06-1680.04s: Average nan V
# Times 1680.06-1680.04s: Average nan V
# Times 748.48-1680.04s: Average nan V
# Times 748.48-1680.04s: Average nan V
# Times 748.48-1680.05s: Average nan V
# Times 748.48-1680.05s: Average nan V
# Times 748.48-1680.05s: Average nan V
# Times 748.48-1680.05s: Average nan V
# Times 748.48-748.86s: Average 1.017 V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-748.87s: Average nan V
# Times 2032.37-2032.36s: Average nan V
# Times 2032.38-2032.36s: Average nan V
# Times 2032.38-2032.36s: Average nan V
# Times 2032.38-2032.36s: Average nan V
# Times 2032.38-2032.36s: Average nan V
# Times 748.87-2032.37s: Average nan V
# Times 748.88-2032.37s: Average nan V
# Times 748.88-2032.37s: Average nan V
# Times 748.88-2032.37s: Average nan V
# Times 748.88-2032.37s: Average nan V
# Times 748.88-749.00s: Average 1.017 V
# Times 1143.17-749.00s: Average nan V
# Times 1143.17-749.00s: Average nan V
# Times 1143.17-749.00s: Average nan V
# Times 1143.17-749.00s: Average nan V
# Times 1143.17-1143.17s: Average nan V
# Times 749.01-749.46s: Average 1.017 V
# Times 2518.92-749.47s: Average nan V
# Times 2518.92-749.47s: Average nan V
# Times 2518.92-749.47s: Average nan V
# Times 2518.92-749.47s: Average nan V
# Times 2518.92-2518.92s: Average 0.238 V
# Times 749.48-750.24s: Average 1.017 V
# Times 2267.26-750.24s: Average nan V
# Times 2267.26-750.24s: Average nan V
# Times 2267.26-750.24s: Average nan V
# Times 2267.26-750.24s: Average nan V
# Times 2267.26-2267.26s: Average 0.277 V
# Times 750.26-750.51s: Average 1.017 V
# Times 3642.99-750.51s: Average nan V
# Times 3642.99-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-750.51s: Average nan V
# Times 3643.00-3642.99s: Average nan V
# Times 3643.00-3642.99s: Average nan V
# Times 3643.00-3642.99s: Average nan V
# Times 3643.01-3642.99s: Average nan V
# Times 3643.01-3642.99s: Average nan V
# Times 750.52-3642.99s: Average nan V
# Times 750.52-3642.99s: Average nan V
# Times 750.52-3642.99s: Average nan V
# Times 750.52-3642.99s: Average nan V
# Times 750.52-3643.00s: Average nan V
# Times 750.52-3643.00s: Average nan V
# Times 750.52-751.64s: Average 1.017 V
# Times 2686.69-751.64s: Average nan V
# Times 2686.69-751.64s: Average nan V
# Times 2686.69-751.64s: Average nan V
# Times 2686.69-751.64s: Average nan V
# Times 2686.69-2686.69s: Average 0.277 V
# Times 751.66-752.17s: Average 1.017 V
# Times 3122.90-752.17s: Average nan V
# Times 3122.90-752.17s: Average nan V
# Times 3122.90-752.17s: Average nan V
# Times 3122.90-752.17s: Average nan V
# Times 3122.90-752.18s: Average nan V
# Times 3122.90-752.18s: Average nan V
# Times 3122.90-752.18s: Average nan V
# Times 3122.90-752.18s: Average nan V
# Times 3122.91-752.18s: Average nan V
# Times 3122.91-752.18s: Average nan V
# Times 3122.91-3122.89s: Average nan V
# Times 3122.91-3122.90s: Average nan V
# Times 3122.91-3122.90s: Average nan V
# Times 3122.91-3122.90s: Average nan V
# Times 3122.91-3122.90s: Average nan V
# Times 3122.91-3122.90s: Average nan V
# Times 752.18-3122.90s: Average nan V
# Times 752.18-3122.90s: Average nan V
# Times 752.18-3122.90s: Average nan V
# Times 752.18-3122.90s: Average nan V
# Times 752.19-3122.90s: Average nan V
# Times 752.19-3122.90s: Average nan V
# Times 752.19-752.77s: Average 1.017 V
# Times 3072.55-752.77s: Average nan V
# Times 3072.55-752.77s: Average nan V
# Times 3072.55-752.77s: Average nan V
# Times 3072.55-3072.56s: Average 0.285 V
# Times 752.79-753.37s: Average 1.017 V
# Times 589.53-753.37s: Average nan V
# Times 589.53-753.37s: Average nan V
# Times 589.53-589.53s: Average 0.277 V
# Times 753.39-753.55s: Average 1.017 V
# Times 589.53-753.55s: Average nan V
# Times 589.53-753.55s: Average nan V
# Times 589.53-753.55s: Average nan V
# Times 589.53-753.55s: Average nan V
# Times 589.53-753.55s: Average nan V
# Times 589.53-753.55s: Average nan V
# Times 589.53-753.55s: Average nan V
# Times 589.53-753.55s: Average nan V
# Times 589.53-589.52s: Average nan V
# Times 589.54-589.52s: Average nan V
# Times 589.54-589.52s: Average nan V
# Times 589.54-589.52s: Average nan V
# Times 589.54-589.52s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 753.56-589.53s: Average nan V
# Times 753.56-589.53s: Average nan V
# Times 753.56-589.53s: Average nan V
# Times 753.56-589.53s: Average nan V
# Times 753.56-589.53s: Average nan V
# Times 753.56-589.53s: Average nan V
# Times 753.57-753.59s: Average 1.017 V
# Times 2669.91-753.60s: Average nan V
# Times 2669.91-753.60s: Average nan V
# Times 2669.91-753.60s: Average nan V
# Times 2669.91-753.60s: Average nan V
# Times 2669.91-753.60s: Average nan V
# Times 2669.91-753.60s: Average nan V
# Times 2669.91-753.60s: Average nan V
# Times 2669.91-753.60s: Average nan V
# Times 2669.92-2669.90s: Average nan V
# Times 2669.92-2669.90s: Average nan V
# Times 2669.92-2669.90s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 2669.92-2669.91s: Average nan V
# Times 753.60-2669.91s: Average nan V
# Times 753.60-2669.91s: Average nan V
# Times 753.60-2669.91s: Average nan V
# Times 753.61-2669.91s: Average nan V
# Times 753.61-2669.91s: Average nan V
# Times 753.61-2669.91s: Average nan V
# Times 753.61-2669.91s: Average nan V
# Times 753.61-754.37s: Average 1.017 V
# Times 2653.13-754.37s: Average nan V
# Times 2653.13-754.37s: Average nan V
# Times 2653.13-754.37s: Average nan V
# Times 2653.13-754.37s: Average nan V
# Times 2653.13-754.37s: Average nan V
# Times 2653.14-754.37s: Average nan V
# Times 2653.14-754.37s: Average nan V
# Times 2653.14-754.38s: Average nan V
# Times 2653.14-754.38s: Average nan V
# Times 2653.14-2653.13s: Average nan V
# Times 2653.14-2653.13s: Average nan V
# Times 2653.14-2653.13s: Average nan V
# Times 2653.14-2653.13s: Average nan V
# Times 2653.14-2653.13s: Average nan V
# Times 2653.14-2653.13s: Average nan V
# Times 754.38-2653.13s: Average nan V
# Times 754.38-2653.13s: Average nan V
# Times 754.38-2653.13s: Average nan V
# Times 754.38-2653.14s: Average nan V
# Times 754.39-2653.14s: Average nan V
# Times 754.39-2653.14s: Average nan V
# Times 754.39-754.48s: Average 1.017 V
# Times 1344.50-754.48s: Average nan V
# Times 1344.50-754.48s: Average nan V
# Times 1344.50-754.48s: Average nan V
# Times 1344.50-754.48s: Average nan V
# Times 1344.50-754.48s: Average nan V
# Times 1344.50-754.49s: Average nan V
# Times 1344.50-754.49s: Average nan V
# Times 1344.50-754.49s: Average nan V
# Times 1344.50-1344.49s: Average nan V
# Times 1344.51-1344.49s: Average nan V
# Times 1344.51-1344.49s: Average nan V
# Times 1344.51-1344.49s: Average nan V
# Times 1344.51-1344.49s: Average nan V
# Times 1344.51-1344.49s: Average nan V
# Times 1344.51-1344.50s: Average nan V
# Times 754.49-1344.50s: Average nan V
# Times 754.49-1344.50s: Average nan V
# Times 754.49-1344.50s: Average nan V
# Times 754.49-1344.50s: Average nan V
# Times 754.50-1344.50s: Average nan V
# Times 754.50-1344.50s: Average nan V
# Times 754.50-754.70s: Average 1.017 V
# Times 2284.03-754.70s: Average nan V
# Times 2284.03-754.70s: Average nan V
# Times 2284.03-754.70s: Average nan V
# Times 2284.03-754.71s: Average nan V
# Times 2284.03-754.71s: Average nan V
# Times 2284.03-754.71s: Average nan V
# Times 2284.03-754.71s: Average nan V
# Times 2284.03-754.71s: Average nan V
# Times 2284.03-754.71s: Average nan V
# Times 2284.03-754.71s: Average nan V
# Times 2284.03-2284.02s: Average nan V
# Times 2284.04-2284.02s: Average nan V
# Times 2284.04-2284.02s: Average nan V
# Times 2284.04-2284.02s: Average nan V
# Times 2284.04-2284.02s: Average nan V
# Times 2284.04-2284.03s: Average nan V
# Times 754.71-2284.03s: Average nan V
# Times 754.71-2284.03s: Average nan V
# Times 754.72-2284.03s: Average nan V
# Times 754.72-2284.03s: Average nan V
# Times 754.72-2284.03s: Average nan V
# Times 754.72-754.90s: Average 1.017 V
# Times 589.54-754.90s: Average nan V
# Times 589.54-754.90s: Average nan V
# Times 589.54-754.90s: Average nan V
# Times 589.54-754.91s: Average nan V
# Times 589.54-754.91s: Average nan V
# Times 589.54-754.91s: Average nan V
# Times 589.54-754.91s: Average nan V
# Times 589.54-754.91s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.55-589.53s: Average nan V
# Times 589.55-589.53s: Average nan V
# Times 589.55-589.53s: Average nan V
# Times 589.55-589.53s: Average nan V
# Times 589.55-589.54s: Average nan V
# Times 589.55-589.54s: Average nan V
# Times 589.55-589.54s: Average nan V
# Times 754.91-589.54s: Average nan V
# Times 754.91-589.54s: Average nan V
# Times 754.91-589.54s: Average nan V
# Times 754.92-589.54s: Average nan V
# Times 754.92-589.54s: Average nan V
# Times 754.92-589.54s: Average nan V
# Times 754.92-756.10s: Average 1.017 V
# Times 589.53-756.10s: Average nan V
# Times 589.53-756.10s: Average nan V
# Times 589.53-756.10s: Average nan V
# Times 589.53-756.10s: Average nan V
# Times 589.53-756.11s: Average nan V
# Times 589.54-756.11s: Average nan V
# Times 589.54-756.11s: Average nan V
# Times 589.54-589.52s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 589.54-589.53s: Average nan V
# Times 756.11-589.53s: Average nan V
# Times 756.11-589.53s: Average nan V
# Times 756.11-589.53s: Average nan V
# Times 756.12-589.53s: Average nan V
# Times 756.12-589.54s: Average nan V
# Times 756.12-589.54s: Average nan V
